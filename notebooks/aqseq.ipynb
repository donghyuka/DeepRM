# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import seaborn as sns
import glob
import tqdm
from scipy import stats

# %%
# Load data
data = pd.read_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq12.2-2.tsv", sep="\t") 

for rep in ['rep1', 'rep2']:
    sum_reads = data[f'nreads_{rep}'].sum()
    ratio = 1 / (4 ** 4)
    ## Normal approximation to the hypergeometric distribution. 
    normal_approx = stats.norm(sum_reads * ratio, np.sqrt(sum_reads * ratio * (1 - ratio)).astype(np.float64))
    ## Apply Continuity correction
    p = 1 - normal_approx.cdf(data[f'nreads_{rep}'] - 0.5)
    data[f'p_{rep}'] = p
    ## Spply Benjamini-Hochberg procedure
    data = data.sort_values(f'p_{rep}', ascending=True)
    data["rank_temp"] = range(1, len(data) + 1)
    data[f'q_{rep}'] = data[f'p_{rep}'] * len(data) / data["rank_temp"]
    data = data.drop(columns=["rank_temp"])
    data[f"fold_{rep}"] = data[f'nreads_{rep}'] / (sum_reads * ratio)

data = data.sort_values("percent_avg", ascending=False)
print(data[(data["q_rep1"] < 0.05) & (data["q_rep2"] < 0.05)])
data.to_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq12.2-2.qvalue.tsv", sep="\t", index=False)
# Out:
#     rank    seq  nreads_rep1  percent_rep1  nreads_rep2  percent_rep2  \
# 0      1  GG+GG       160543      3.473469       127495      3.086937
# 1      2  AC+GA       115314      2.494905       110557      2.676830
# 2      3  CC+GA       111807      2.419029       105824      2.562234
# 3      4  GA+CG       110899      2.399383       105587      2.556496
# 4      5  TC+CG       108509      2.347674       102301      2.476934
# 5      6  AG+TC       108222      2.341465       100687      2.437856
# 6      7  CG+AC       106790      2.310482       101049      2.446621
# 7      8  CA+GT       107260      2.320651        99523      2.409673
# 8      9  CG+AT       104007      2.250270       101267      2.451899
# 9     10  GA+TC       103635      2.242221       101109      2.448073
# 10    11  AC+AG       103264      2.234194        94399      2.285609
# 11    12  GT+CC       102347      2.214355        94484      2.287667
# ...

# %%
# Load data
data = pd.read_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq12.4-4.tsv", sep="\t")

for rep in ['rep1', 'rep2']:
    sum_reads = data[f'nreads_{rep}'].sum()
    ratio = 1 / (4 ** 8)
    ## Normal approximation to the hypergeometric distribution. 
    normal_approx = stats.norm(sum_reads * ratio, np.sqrt(sum_reads * ratio * (1 - ratio)).astype(np.float64))
    ## Apply Continuity correction
    p = 1 - normal_approx.cdf(data[f'nreads_{rep}'] - 0.5)
    data[f'p_{rep}'] = p
    ## apply Benjamini-Hochberg procedure
    data = data.sort_values(f'p_{rep}', ascending=True)
    data["rank_temp"] = range(1, len(data) + 1)
    data[f'q_{rep}'] = data[f'p_{rep}'] * len(data) / data["rank_temp"]
    data = data.drop(columns=["rank_temp"])
    data[f"fold_{rep}"] = data[f'nreads_{rep}'] / (sum_reads * ratio)

data = data.sort_values("percent_avg", ascending=False)
print(data[(data["q_rep1"] < 0.05) & (data["q_rep2"] < 0.05)])
data.to_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq12.4-4.qvalue.tsv", sep="\t", index=False)
# Out:
#       rank      index  nreads_rep1  percent_rep1  nreads_rep2  percent_rep2  \
# 0        1  AGTC+CGAC      83502.0      1.806629      79234.0      1.918431
# 1        2  CGAC+GATC      82230.0      1.779108      80290.0      1.943999
# 2        3  GTCC+GACG      80829.0      1.748796      77239.0      1.870128
# 3        4  CCGA+CGAT      79404.0      1.717965      76994.0      1.864196
# 4        5  TCCG+ACGA      75257.0      1.628242      72320.0      1.751028
# ...    ...        ...          ...           ...          ...           ...
# 5455  5456  TTGC+GTTC         95.0      0.002055         85.0      0.002058
# 5453  5454  GGCG+ACAG         95.0      0.002055         85.0      0.002058
# 5486  5487  TGCA+TACA         94.0      0.002034         85.0      0.002058
# 5487  5488  CGCA+AGGA         94.0      0.002034         85.0      0.002058
# 5488  5489  GCCA+GAAA         94.0      0.002034         85.0      0.002058
#
# ...

# %%
# Load data
data = pd.read_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq12.3-3.tsv", sep="\t")

for rep in ['rep1', 'rep2']:
    sum_reads = data[f'nreads_{rep}'].sum()
    ratio = 1 / (4 ** 6)
    ## Normal approximation to the hypergeometric distribution. 
    normal_approx = stats.norm(sum_reads * ratio, np.sqrt(sum_reads * ratio * (1 - ratio)).astype(np.float64))
    ## Apply Continuity correction
    p = 1 - normal_approx.cdf(data[f'nreads_{rep}'] - 0.5)
    data[f'p_{rep}'] = p
    ## apply Benjamini-Hochberg procedure
    data = data.sort_values(f'p_{rep}', ascending=True)
    data["rank_temp"] = range(1, len(data) + 1)
    data[f'q_{rep}'] = data[f'p_{rep}'] * len(data) / data["rank_temp"]
    data = data.drop(columns=["rank_temp"])
    data[f"fold_{rep}"] = data[f'nreads_{rep}'] / (sum_reads * ratio)

data = data.sort_values("percent_avg", ascending=False)
print(data[(data["q_rep1"] < 0.05) & (data["q_rep2"] < 0.05)])
data.to_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq12.3-3.qvalue.tsv", sep="\t", index=False)
# Out:
#      rank    index  nreads_rep1  percent_rep1  nreads_rep2  percent_rep2  \
# 0       1  GAC+GAT        98280      2.126362        95121      2.303090
# 1       2  CGA+CGA        93645      2.026080        90014      2.179439
# 2       3  GTC+CGA        92300      1.996980        87237      2.112201
# 3       4  ACG+ATC        89371      1.933609        87569      2.120240
# 4       5  TCC+GAC        89777      1.942393        85667      2.074188
# ..    ...      ...          ...           ...          ...           ...
# 499   500  TCA+CGA         1238      0.026785         1120      0.027118
# 501   502  AGA+AGG         1249      0.027023         1098      0.026585
# 502   503  CCG+TTC         1231      0.026634         1113      0.026948
# 507   508  TGC+TAC         1229      0.026590         1095      0.026512
# 511   512  CCA+GAC         1216      0.026309         1092      0.026440
#
#      percent_avg    p_rep1    q_rep1  fold_rep1    p_rep2    q_rep2  fold_rep2
# ...

# %%
# Load data
data = pd.read_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq45.2-2.tsv", sep="\t")

for rep in ['rep1', 'rep2']:
    sum_reads = data[f'nreads_{rep}'].sum()
    ratio = 1 / (4 ** 4)
    ## Normal approximation to the hypergeometric distribution. 
    normal_approx = stats.norm(sum_reads * ratio, np.sqrt(sum_reads * ratio * (1 - ratio)).astype(np.float64))
    ## Apply Continuity correction
    p = 1 - normal_approx.cdf(data[f'nreads_{rep}'] - 0.5)
    data[f'p_{rep}'] = p
    ## Spply Benjamini-Hochberg procedure
    data = data.sort_values(f'p_{rep}', ascending=True)
    data["rank_temp"] = range(1, len(data) + 1)
    data[f'q_{rep}'] = data[f'p_{rep}'] * len(data) / data["rank_temp"]
    data = data.drop(columns=["rank_temp"])
    data[f"fold_{rep}"] = data[f'nreads_{rep}'] / (sum_reads * ratio)

data = data.sort_values("percent_avg", ascending=False)
print(data[(data["q_rep1"] < 0.05) & (data["q_rep2"] < 0.05)])
data.to_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq45.2-2.qvalue.tsv", sep="\t", index=False)
# Out:
#      rank    seq  nreads_rep1  percent_rep1  nreads_rep2  percent_rep2  \
# 0       1  CG+AG      58731.0      1.270771      50194.0      1.215382
# 1       2  TT+GG      51525.0      1.114854      45446.0      1.100416
# 2       3  CC+GA      49839.0      1.078374      42993.0      1.041019
# 3       4  TG+GA      43497.0      0.941151      38644.0      0.935714
# 4       5  GC+AA      43296.0      0.936802      38576.0      0.934068
# ..    ...    ...          ...           ...          ...           ...
# 102   103  GC+TG      19085.0      0.412945      16911.0      0.409478
# 103   104  AG+GT      19000.0      0.411106      16650.0      0.403158
# 104   105  GG+AT      19078.0      0.412794      16501.0      0.399550
# 105   106  GT+AC      18834.0      0.407514      16701.0      0.404393
# 106   107  CG+AC      18637.0      0.403252      16790.0      0.406548
#
#      percent_avg        p_rep1        q_rep1  fold_rep1        p_rep2  \
# ...

# %%
# Load data
data = pd.read_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq45.3-3.tsv", sep="\t")

for rep in ['rep1', 'rep2']:
    sum_reads = data[f'nreads_{rep}'].sum()
    ratio = 1 / (4 ** 6)
    ## Normal approximation to the hypergeometric distribution. 
    normal_approx = stats.norm(sum_reads * ratio, np.sqrt(sum_reads * ratio * (1 - ratio)).astype(np.float64))
    ## Apply Continuity correction
    p = 1 - normal_approx.cdf(data[f'nreads_{rep}'] - 0.5)
    data[f'p_{rep}'] = p
    ## apply Benjamini-Hochberg procedure
    data = data.sort_values(f'p_{rep}', ascending=True)
    data["rank_temp"] = range(1, len(data) + 1)
    data[f'q_{rep}'] = data[f'p_{rep}'] * len(data) / data["rank_temp"]
    data = data.drop(columns=["rank_temp"])
    data[f"fold_{rep}"] = data[f'nreads_{rep}'] / (sum_reads * ratio)

data = data.sort_values("percent_avg", ascending=False)
print(data[(data["q_rep1"] < 0.05) & (data["q_rep2"] < 0.05)])
data.to_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq45.3-3.qvalue.tsv", sep="\t", index=False)
# Out:
#       rank    index  nreads_rep1  percent_rep1  nreads_rep2  percent_rep2  \
# 0        1  CCG+AGA         7720      0.167039         6458      0.156372
# 1        2  TCG+AGA         7549      0.163339         6494      0.157244
# 2        3  TTG+GCA         7554      0.163447         6339      0.153491
# 3        4  CTT+GGC         6601      0.142827         5595      0.135476
# 4        5  CTT+GGA         5995      0.129715         5204      0.126008
# ...    ...      ...          ...           ...          ...           ...
# 1486  1487  GCC+GCG         1219      0.026376         1093      0.026466
# 1493  1494  GGG+ATA         1211      0.026203         1096      0.026538
# 1495  1496  CCC+GCA         1222      0.026441         1084      0.026248
# 1499  1500  GTT+TAG         1212      0.026224         1086      0.026296
# 1503  1504  ATG+GCC         1216      0.026311         1080      0.026151
#
#       percent_avg    p_rep1    q_rep1  fold_rep1    p_rep2    q_rep2  \
# ...

# %%
# Load data
data = pd.read_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq45.4-4.tsv", sep="\t")

for rep in ['rep1', 'rep2']:
    sum_reads = data[f'nreads_{rep}'].sum()
    ratio = 1 / (4 ** 8)
    ## Normal approximation to the hypergeometric distribution. 
    normal_approx = stats.norm(sum_reads * ratio, np.sqrt(sum_reads * ratio * (1 - ratio)).astype(np.float64))
    ## Apply Continuity correction
    p = 1 - normal_approx.cdf(data[f'nreads_{rep}'] - 0.5)
    data[f'p_{rep}'] = p
    ## apply Benjamini-Hochberg procedure
    data = data.sort_values(f'p_{rep}', ascending=True)
    data["rank_temp"] = range(1, len(data) + 1)
    data[f'q_{rep}'] = data[f'p_{rep}'] * len(data) / data["rank_temp"]
    data = data.drop(columns=["rank_temp"])
    data[f"fold_{rep}"] = data[f'nreads_{rep}'] / (sum_reads * ratio)

data = data.sort_values("percent_avg", ascending=False)
print(data[(data["q_rep1"] < 0.05) & (data["q_rep2"] < 0.05)])
data.to_csv("/extdata4/baeklab/Hyeonseo/m6A/aqseq/dimers.rep56.seq45.4-4.qvalue.tsv", sep="\t", index=False)
# Out:
#         rank      index  nreads_rep1  percent_rep1  nreads_rep2  percent_rep2  \
# 0          1  CTCG+AGAA         1254      0.027133         1054      0.025521
# 1          2  CCTT+GGCA         1103      0.023866          958      0.023197
# 2          3  ACCG+AGAA         1090      0.023584          857      0.020751
# 3          4  TCCG+AGAA         1034      0.022373          868      0.021017
# 4          5  ACTT+GGCA          972      0.021031          836      0.020243
# ...      ...        ...          ...           ...          ...           ...
# 17900  17901  ACGG+GTAC           90      0.001947           81      0.001961
# 17894  17895  CATC+GCCA           90      0.001947           81      0.001961
# 17893  17894  TCAG+AGCT           90      0.001947           81      0.001961
# 17898  17899  AATG+ACAG           90      0.001947           81      0.001961
# 17899  17900  CAAT+ACGT           90      0.001947           81      0.001961
#
# ...
