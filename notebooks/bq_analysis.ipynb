# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import seaborn as sns
import sys
sys.path.append("/extdata4/baeklab/Hyeonseo/m6A/modformer")
from utils.utils import printmessage
import glob
import tqdm
import gc

# %%
block_ON0099_df = pd.read_pickle(f"/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0099/result/dorado-070/intermediates/block_df.pkl")
print(block_ON0099_df)
# Out:
#           cb_idx  start_pos  end_pos  pos_RM  penalty     score  \
# 0              2        165      186     175        6  0.857143
# 1              1        220      241     230        9  0.785714
# 2              2        247      268     257        0  1.000000
# 3              0        452      473     462        0  1.000000
# 4              1        478      499     488        3  0.928571
# ...          ...        ...      ...     ...      ...       ...
# 77735403       2          9       30      19       10  0.761905
# 77735404       2          5       26      15        9  0.785714
# 77735405       0          9       30      19        4  0.904762
# 77735406       1         14       35      24       10  0.761905
# 77735407       1         12       33      22       15  0.642857
#
#                                        read_id  total_score  \
# 0         626a5a68-924d-4cde-96ad-1e1fa86ccf62    19.142857
# 1         626a5a68-924d-4cde-96ad-1e1fa86ccf62    19.142857
# ...

# %%
block_ON0099_df["11mer"] = block_ON0099_df["motif"].apply(lambda x: x[5:-5])
motif_count_ON0099 = block_ON0099_df["11mer"].value_counts()
print(motif_count_ON0099)
# Out:
# 11mer
# AAAAAAAAAAA    11908
# CCACCACCACC     3294
# CAAAAAAAAAA     1568
# UAAAAAAAAAA     1090
# CACACACACAC     1075
#                ...
# GUUUAAGGGAU        1
# GGAAAAGGGGA        1
# ACGUAAGAGAU        1
# GAGAGAGGGAC        1
# UGUUAAGGGGA        1
# Name: count, Length: 1048569, dtype: int64

# %%
motif_count_ON0099.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0099/result/dorado-070/intermediates/11mer_count.pkl")
del block_ON0099_df
gc.collect()
# Out:
# 5008

# %%
motif_count_ON0099 = pd.read_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0099/result/dorado-070/intermediates/11mer_count.pkl")
print(motif_count_ON0099)
# Out:
# 11mer
# AAAAAAAAAAA    11908
# CCACCACCACC     3294
# CAAAAAAAAAA     1568
# UAAAAAAAAAA     1090
# CACACACACAC     1075
#                ...
# GUUUAAGGGAU        1
# GGAAAAGGGGA        1
# ACGUAAGAGAU        1
# GAGAGAGGGAC        1
# UGUUAAGGGGA        1
# Name: count, Length: 1048569, dtype: int64

# %%
block_ON0098_df = pd.read_pickle(f"/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0098/result/dorado-070/intermediates/block_df.pkl")
print(block_ON0098_df)
# Out:
#           cb_idx  start_pos  end_pos  pos_RM  penalty     score  \
# 0              1          5       26      15        7  0.833333
# 1              1         86      107      96        7  0.833333
# 2              2        113      134     123        2  0.952381
# 3              0        147      168     157        8  0.809524
# 4              1        173      194     183        2  0.952381
# ...          ...        ...      ...     ...      ...       ...
# 70833004       2          8       29      18        0  1.000000
# 70833005       2          9       30      19        9  0.785714
# 70833006       2          9       30      19        9  0.785714
# 70833007       0          4       25      14       12  0.714286
# 70833008       2          8       29      18       13  0.690476
#
#                                        read_id  total_score  \
# 0         8453a68c-1981-467b-96d9-e0f10bd80307    27.214286
# 1         8453a68c-1981-467b-96d9-e0f10bd80307    27.214286
# ...

# %%
block_ON0098_df["11mer"] = block_ON0098_df["motif"].apply(lambda x: x[5:-5])
motif_count_ON0098 = block_ON0098_df["11mer"].value_counts()
print(motif_count_ON0098)
# Out:
# 11mer
# AAAAAAAAAAA    9850
# CCACCACCACC    3171
# GCGCCACCUCC    1390
# GCGCCACCUCU    1271
# CAAAAAAAAAA    1247
#                ...
# UCGUAAGAACU       1
# UAGUAAGAGAC       1
# UACUAAGAUUC       1
# ACCUAAGCGAC       1
# GUCGAAGGUAA       1
# Name: count, Length: 1048431, dtype: int64

# %%
motif_count_ON0098.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0098/result/dorado-070/intermediates/11mer_count.pkl")
del block_ON0098_df

# %%
gc.collect()
# Out:
# 517

# %%
block_ON0093_df = pd.read_pickle(f"/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0093/ON0093/result/dorado-070/intermediates/block_df.pkl")
print(block_ON0093_df)
# Out:
#           cb_idx  start_pos  end_pos  pos_RM  penalty     score  \
# 0              1         13       34      23        9  0.785714
# 1              2         40       61      50        3  0.928571
# 2              2        124      145     134        0  1.000000
# 3              1        252      273     262        8  0.809524
# 4              1        431      452     441        7  0.833333
# ...          ...        ...      ...     ...      ...       ...
# 57078601       2          8       29      18       10  0.761905
# 57078602       2          7       28      17       10  0.761905
# 57078603       2          4       25      14       15  0.642857
# 57078604       2          7       28      17       12  0.714286
# 57078605       2          6       27      16       15  0.642857
#
#                                        read_id  total_score  \
# 0         c9c22acf-01fb-491b-aaa6-e7623556c32d    17.547619
# 1         c9c22acf-01fb-491b-aaa6-e7623556c32d    17.547619
# ...

# %%
block_ON0093_df["11mer"] = block_ON0093_df["motif"].apply(lambda x: x[5:-5])
motif_count_ON0093 = block_ON0093_df["11mer"].value_counts()
print(motif_count_ON0093)
motif_count_ON0093.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0093/ON0093/result/dorado-070/intermediates/11mer_count.pkl")
del block_ON0093_df
gc.collect()
# Out:
# 11mer
# AAAAAAAAAAA    6604
# CCACCACCACC    2315
# GCGCCACCUCC    1074
# GCGCCACCUCU    1006
# GCGCCACCAGC     946
#                ...
# UCCGGAGAGUA       1
# CUAAGAGGGAU       1
# GUUAGAGAUCC       1
# UCUGAAGACGU       1
# ACGUAAGGGGA       1
# Name: count, Length: 1048140, dtype: int64
# 16

# %%
block_ON0092_df = pd.read_pickle(f"/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0092/ON0092/result/dorado-070/intermediates/block_df.pkl")
print(block_ON0092_df)
# Out:
#            cb_idx  start_pos  end_pos  pos_RM  penalty     score  \
# 0               2         24       45      34        2  0.952381
# 1               0         57       78      67        0  1.000000
# 2               1         84      105      94        0  1.000000
# 3               2        111      132     121        0  1.000000
# 4               0        144      165     154        0  1.000000
# ...           ...        ...      ...     ...      ...       ...
# 128973864       2          5       26      15       12  0.714286
# 128973865       2          9       30      19        6  0.857143
# 128973866       2          8       29      18       15  0.642857
# 128973867       1          9       30      19       12  0.714286
# 128973868       1          8       29      18       15  0.642857
#
#                                         read_id  total_score  \
# 0          f2667780-9131-4827-8c8e-a26b25b51fa1    33.404762
# ...

# %%
block_ON0092_df["11mer"] = block_ON0092_df["motif"].apply(lambda x: x[5:-5])
motif_count_ON0092 = block_ON0092_df["11mer"].value_counts()
print(motif_count_ON0092)
motif_count_ON0092.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0092/ON0092/result/dorado-070/intermediates/11mer_count.pkl")
del block_ON0092_df
gc.collect()
# Out:
# 11mer
# AAAAAAAAAAA    18394
# CCACCACCACC     4070
# CAAAAAAAAAA     1967
# UAAAAAAAAAA     1594
# GUGAAACUGAA     1308
#                ...
# UUUCGAGGGGA       17
# GUGAGAGUGUG       17
# GGGGGAGGAGA       17
# UGAGGAGGAGU       16
# GGUGGAGGAGG       13
# Name: count, Length: 1048576, dtype: int64
# 509

# %%
block_ON0096_df = pd.read_pickle(f"/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0096/result/dorado-070/intermediates/block_df.pkl")
print(block_ON0096_df)
# Out:
#            cb_idx  start_pos  end_pos  pos_RM  penalty     score  \
# 0               1         19       40      29        0  1.000000
# 1               2         46       67      56        0  1.000000
# 2               0         79      100      89        0  1.000000
# 3               1        106      127     116        0  1.000000
# 4               2        133      154     143        0  1.000000
# ...           ...        ...      ...     ...      ...       ...
# 177948227       2          6       27      16        9  0.785714
# 177948228       2          8       29      18       12  0.714286
# 177948229       2          6       27      16        5  0.880952
# 177948230       2          7       28      17        2  0.952381
# 177948231       2          9       30      19       12  0.714286
#
#                                         read_id  total_score  \
# 0          93e7d60b-ddf6-4c2c-b368-8fec673dce94    37.023810
# ...

# %%
block_ON0096_df["11mer"] = block_ON0096_df["motif"].apply(lambda x: x[5:-5])
motif_count_ON0096 = block_ON0096_df["11mer"].value_counts()
print(motif_count_ON0096)

# %%
motif_count_ON0096.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0096/result/dorado-070/intermediates/11mer_count.pkl")
del block_ON0096_df
gc.collect()
# Out:
# 1983

# %%
motif_count_ON0092 = pd.read_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0092/ON0092/result/dorado-070/intermediates/11mer_count.pkl")
motif_count_ON0096 = pd.read_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0096/result/dorado-070/intermediates/11mer_count.pkl")
motif_count_ON0093 = pd.read_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0093/ON0093/result/dorado-070/intermediates/11mer_count.pkl")
motif_count_ON0098 = pd.read_pickle("/extdata4/baeklab/Hyeonseo/m6A/runs/exp_BB87/ON0098/result/dorado-070/intermediates/11mer_count.pkl")

# %%
ca_list = [motif_count_ON0092, motif_count_ON0096]
m6a_list = [motif_count_ON0093, motif_count_ON0098]

# %%
ca_df = pd.concat(ca_list, axis=1).fillna(0).sum(axis=1)
print(ca_df)
m6a_df = pd.concat(m6a_list, axis=1).fillna(0).sum(axis=1)
print(m6a_df)
# Out:
# 11mer
# AAAAAAAAAAA    30453
# CCACCACCACC     6955
# CAAAAAAAAAA     3298
# UAAAAAAAAAA     2671
# GUGAAACUGAA     2164
#                ...
# UUUCGAGGGGA       66
# GUGAGAGUGUG       78
# GGGGGAGGAGA       55
# UGAGGAGGAGU       59
# GGUGGAGGAGG       47
# Length: 1048576, dtype: int64
# 11mer
# AAAAAAAAAAA    16454.0
# CCACCACCACC     5486.0
# GCGCCACCUCC     2464.0
# GCGCCACCUCU     2277.0
# GCGCCACCAGC     2033.0
#                 ...
# UUUUAAGAUGA        1.0
# CGAAGAGAGUU        1.0
# GUGAGAGUAGG        1.0
# UAUAGAGAGUA        1.0
# UAUUAAGAAGA        1.0
# Length: 1048569, dtype: float64

# %%
ca_df = pd.DataFrame(ca_df)
m6a_df = pd.DataFrame(m6a_df)
ca_df.columns = ["count"]
m6a_df.columns = ["count"]
ca_df["11mer"] = ca_df.index
m6a_df["11mer"] = m6a_df.index
ca_df["9mer"] = ca_df["11mer"].apply(lambda x: x[1:-1])
m6a_df["9mer"] = m6a_df["11mer"].apply(lambda x: x[1:-1])
print(ca_df)
print(m6a_df)
# Out:
#              count        11mer       9mer
# 11mer
# AAAAAAAAAAA  30453  AAAAAAAAAAA  AAAAAAAAA
# CCACCACCACC   6955  CCACCACCACC  CACCACCAC
# CAAAAAAAAAA   3298  CAAAAAAAAAA  AAAAAAAAA
# UAAAAAAAAAA   2671  UAAAAAAAAAA  AAAAAAAAA
# GUGAAACUGAA   2164  GUGAAACUGAA  UGAAACUGA
# ...            ...          ...        ...
# UUUCGAGGGGA     66  UUUCGAGGGGA  UUCGAGGGG
# GUGAGAGUGUG     78  GUGAGAGUGUG  UGAGAGUGU
# GGGGGAGGAGA     55  GGGGGAGGAGA  GGGGAGGAG
# UGAGGAGGAGU     59  UGAGGAGGAGU  GAGGAGGAG
# GGUGGAGGAGG     47  GGUGGAGGAGG  GUGGAGGAG
#
# [1048576 rows x 3 columns]
#                count        11mer       9mer
# 11mer
# AAAAAAAAAAA  16454.0  AAAAAAAAAAA  AAAAAAAAA
# CCACCACCACC   5486.0  CCACCACCACC  CACCACCAC
# GCGCCACCUCC   2464.0  GCGCCACCUCC  CGCCACCUC
# GCGCCACCUCU   2277.0  GCGCCACCUCU  CGCCACCUC
# GCGCCACCAGC   2033.0  GCGCCACCAGC  CGCCACCAG
# ...              ...          ...        ...
# UUUUAAGAUGA      1.0  UUUUAAGAUGA  UUUAAGAUG
# ...

# %%
ca_df_count_9mer = ca_df.groupby("9mer")[["count"]].sum()
m6a_df_count_9mer = m6a_df.groupby("9mer")[["count"]].sum()

print(ca_df_count_9mer)
print(m6a_df_count_9mer)
# Out:
#            count
# 9mer
# AAAAAAAAA  43674
# AAAAAAAAC   4166
# AAAAAAAAG   5793
# AAAAAAAAU   5767
# AAAAAAACA   5342
# ...          ...
# UUUUAUUGU   4919
# UUUUAUUUA   5413
# UUUUAUUUC   4551
# UUUUAUUUG   5530
# UUUUAUUUU   5810
#
# [65536 rows x 1 columns]
#              count
# 9mer
# AAAAAAAAA  23347.0
# AAAAAAAAC    831.0
# AAAAAAAAG   1324.0
# AAAAAAAAU   1689.0
# AAAAAAACA    665.0
# ...            ...
# UUUUAUUGU   2911.0
# UUUUAUUUA   3922.0
# UUUUAUUUC   1220.0
# UUUUAUUUG   2473.0
# UUUUAUUUU   2060.0
#
# [65536 rows x 1 columns]

# %%
## Plot inverse CDF
fig, ax = plt.subplots(figsize=(10, 10))


ax.plot(np.linspace(0, 1, len(ca_df_count_9mer), endpoint=False),  np.log10(np.sort(ca_df_count_9mer["count"].values)[::-1]), label="A", color="royalblue")
ax.plot(np.linspace(0, 1, len(m6a_df_count_9mer), endpoint=False), np.log10(np.sort(m6a_df_count_9mer["count"].values)[::-1]), label="m6A", color="tomato")
ax.set_xlabel("Fraction")
ax.set_ylabel("log10(Count)")
ax.set_ylim(0, 4.5)
ax.legend()
plt.savefig("/extdata4/baeklab/Hyeonseo/m6A/poster/motif_cdf_9mer.pdf")
plt.show()

# %%
## Plot inverse CDF
fig, ax = plt.subplots(figsize=(10, 10))


ax.plot(np.linspace(0, 1, len(ca_df), endpoint=False),  np.log10(np.sort(ca_df.values)[::-1]), label="A", color="royalblue")
ax.plot(np.linspace(0, 1, len(m6a_df), endpoint=False), np.log10(np.sort(m6a_df.values)[::-1]), label="m6A", color="tomato")
ax.set_xlabel("Fraction")
ax.set_ylabel("log10(Count)")
ax.set_ylim(0, 4.5)
ax.legend()
plt.savefig("/extdata4/baeklab/Hyeonseo/m6A/poster/motif_cdf.pdf")
plt.show()
