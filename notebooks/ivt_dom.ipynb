# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import seaborn as sns
import glob
import tqdm

# %%
df = pd.read_pickle("/extdata4/baeklab/Hyeonseo/m6A/inference/inference/AIRNA-DW-v2-20240827-175235-22-373000-token_normalise_all_context_dwell-IVT_ON0105_allmotif_pileup/pileup.pkl")

# %%
print(df)
# Out:
#                 label_id      pm6a  count_pm6a       dom  count_dom  mean_pred
# 0         NM_000016:1000  0.002688        63.0  0.000000         68   0.013365
# 1         NM_000016:1008  0.002567        62.0  0.015625         64   0.016574
# 2         NM_000016:1009  0.003085        60.0  0.000000         63   0.008780
# 3         NM_000016:1010  0.005679        63.0  0.028986         69   0.037653
# 4         NM_000016:1014  0.003921        60.0  0.015385         65   0.026991
# ...                  ...       ...         ...       ...        ...        ...
# 11056402   NR_184306:979  0.032642         2.0  0.500000          4   0.415369
# 11056403    NR_184306:98  0.020463        15.0  0.150000         20   0.152749
# 11056404   NR_184306:984  0.005795         5.0  0.000000          5   0.005757
# 11056405   NR_184306:986  0.013035         5.0  0.000000          5   0.012885
# 11056406   NR_184306:997  0.014755         3.0  0.333333          6   0.242574
#
# ...

# %%
dom_arr = df[(df["dom"] > 0) & (df["count_pm6a"] >=20)]["dom"].values
print(len(dom_arr))
plt.hist(dom_arr, bins=100)
plt.yscale("log")
plt.show()
# Out:
# 1844133

# %%
dom_arr = df[df["count_pm6a"] >=20]["dom"].values
print(len(dom_arr))
plt.hist(dom_arr, bins=100)
plt.yscale("log")
plt.show()
# Out:
# 3228977

# %%
dom_arr = df[df["count_pm6a"] >=20]["dom"].values
print(len(dom_arr))
plt.hist(dom_arr, bins=100)
plt.show()
# Out:
# 3228977
