# %%
import gc
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import seaborn as sns
import sys
sys.path.append("/extdata4/baeklab/Hyeonseo/m6A/modformer")
from utils.utils import printmessage
import glob
import tqdm
import gc

# %%
plt.style.use('default')
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({'font.size': 22, 'legend.facecolor': 'white', 'legend.framealpha': 1, "legend.frameon": 1, "lines.linewidth": 2})

# %%
refseq_path = "/extdata4/baeklab/Hyeonseo/m6A/anno/GCF_000001405.40_GRCh38.p14_genomic.gtf"
ensembl_path = "/extdata4/baeklab/Hyeonseo/m6A/anno/Homo_sapiens.GRCh38.113.gtf"

# %%
columns = ["chr", "source", "feature", "start", "end", "score", "strand", "frame", "attribute"]

refseq = pd.read_csv(refseq_path, sep= "\t", skiprows=5, names = columns, dtype={"chr":str})
ensembl = pd.read_csv(ensembl_path, sep= "\t", skiprows=5, names = columns, dtype={"chr":str})

print(refseq)
print(ensembl)

# %%
def ncid_to_chr(ncid):
    ncid_int=ncid.split(".")[0][3:]
    if not ncid_int.isnumeric():
        return "chrUnk"
    else:
        ncid_int = int(ncid_int)
    if ncid_int<=22:
        chr=f"chr{ncid_int}"
    elif ncid_int==23:
        chr="chrX"
    elif ncid_int==24:
        chr="chrY"
    else:
        chr="chrUnk"
    return chr

# %%
valid_chr = ["chr"+str(x) for x in range(1,24)]+["chrX","chrY"]

# %%
refseq["chr"] = refseq["chr"].apply(ncid_to_chr)
refseq_filtered = refseq[refseq["chr"].isin(valid_chr)]
print(refseq_filtered)

# %%
ensembl["chr"] = "chr"+ensembl["chr"]
ensembl_filtered = ensembl[ensembl["chr"].isin(valid_chr)]
print(ensembl_filtered)

# %%
def attribute_to_dict(attribute):
    attribute = attribute+" "
    attribute_dict = {}
    for attr in attribute.split('"; ')[:-1]:
        try:
            key, value = attr.split('"')[:2]
        except:
            print(attribute)
            print(attr)
            raise ValueError
        key = key.strip()
        attribute_dict[key] = value
    return attribute_dict

# %%
print(ensembl_filtered)
# Out:
#            chr          source      feature    start      end score strand  \
# 0         chr1  ensembl_havana         gene  3069168  3438621     .      +
# 1         chr1          havana   transcript  3069168  3434342     .      +
# 2         chr1          havana         exon  3069168  3069296     .      +
# 3         chr1          havana          CDS  3069260  3069296     .      +
# 4         chr1          havana  start_codon  3069260  3069262     .      +
# ...        ...             ...          ...      ...      ...   ...    ...
# 4102141  chr21   havana_tagene         exon  9678230  9678353     .      +
# 4102142  chr21   havana_tagene         exon  9679515  9679891     .      +
# 4102143  chr21   havana_tagene   transcript  9662173  9677705     .      +
# 4102144  chr21   havana_tagene         exon  9662173  9662338     .      +
# 4102145  chr21   havana_tagene         exon  9677372  9677705     .      +
#
#         frame                                          attribute  \
# 0           .  gene_id "ENSG00000142611"; gene_version "17"; ...
# 1           .  gene_id "ENSG00000142611"; gene_version "17"; ...
# 2           .  gene_id "ENSG00000142611"; gene_version "17"; ...
# 3           0  gene_id "ENSG00000142611"; gene_version "17"; ...
# 4           0  gene_id "ENSG00000142611"; gene_version "17"; ...
# ...       ...                                                ...
# 4102141     .  gene_id "ENSG00000293062"; gene_version "2"; t...
# 4102142     .  gene_id "ENSG00000293062"; gene_version "2"; t...
# 4102143     .  gene_id "ENSG00000293062"; gene_version "2"; t...
# 4102144     .  gene_id "ENSG00000293062"; gene_version "2"; t...
# 4102145     .  gene_id "ENSG00000293062"; gene_version "2"; t...
#
#                                             attribute_dict        gene_name  \
# 0        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# 1        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# 2        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# 3        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# 4        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# ...                                                    ...              ...
# 4102141  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
# 4102142  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
# 4102143  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
# 4102144  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
# 4102145  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
#
#            transcript_id          gene_id
# 0                     NA  ENSG00000142611
# 1        ENST00000511072  ENSG00000142611
# 2        ENST00000511072  ENSG00000142611
# 3        ENST00000511072  ENSG00000142611
# 4        ENST00000511072  ENSG00000142611
# ...                  ...              ...
# 4102141  ENST00000842019  ENSG00000293062
# 4102142  ENST00000842019  ENSG00000293062
# 4102143  ENST00000842020  ENSG00000293062
# 4102144  ENST00000842020  ENSG00000293062
# 4102145  ENST00000842020  ENSG00000293062
#
# [4102146 rows x 13 columns]

# %%
print(ensembl_filtered["feature"].value_counts())
print(refseq_filtered["feature"].value_counts())

# %%
print(refseq_filtered[refseq_filtered["feature"]=="exon"]["attribute"].values[0])
# Out:
# gene_id "DDX11L1"; transcript_id "NR_046018.2"; db_xref "GeneID:100287102"; db_xref "GenBank:NR_046018.2"; db_xref "HGNC:HGNC:37102"; gene "DDX11L1"; product "DEAD/H-box helicase 11 like 1 (pseudogene)"; pseudo "true"; transcript_biotype "transcript"; exon_number "1";

# %%
print(ensembl_filtered[ensembl_filtered["feature"]=="exon"]["attribute"].values[0])
# Out:
# gene_id "ENSG00000142611"; gene_version "17"; transcript_id "ENST00000511072"; transcript_version "5"; exon_number "1"; gene_name "PRDM16"; gene_source "ensembl_havana"; gene_biotype "protein_coding"; transcript_name "PRDM16-206"; transcript_source "havana"; transcript_biotype "protein_coding"; exon_id "ENSE00002048533"; exon_version "1"; tag "gencode_basic"; tag "gencode_primary"; transcript_support_level "5";

# %%
ensembl_filtered = ensembl_filtered.copy().reset_index(drop=True)
ensembl_filtered["attribute_dict"] = ensembl_filtered["attribute"].apply(attribute_to_dict)

# %%
refseq_filtered = refseq_filtered.copy().reset_index(drop=True)
refseq_filtered["attribute_dict"] = refseq_filtered["attribute"].apply(attribute_to_dict)

# %%
ensembl_filtered["gene_name"] = ensembl_filtered["attribute_dict"].apply(lambda x: x.get("gene_name", "NA"))
refseq_filtered["gene_name"] = refseq_filtered["attribute_dict"].apply(lambda x: x.get("gene_id", "NA"))

# %%
ensembl_filtered["transcript_id"] = ensembl_filtered["attribute_dict"].apply(lambda x: x.get("transcript_id", "NA"))
refseq_filtered["transcript_id"] = refseq_filtered["attribute_dict"].apply(lambda x: x.get("transcript_id", "NA"))

# %%
ensembl_filtered["gene_id"] = ensembl_filtered["attribute_dict"].apply(lambda x: x.get("gene_id", "NA"))
refseq_filtered["gene_id"] = refseq_filtered["attribute_dict"].apply(lambda x: x.get("gene_id", "NA"))

# %%
ensembl_filtered["gene_name"] = ensembl_filtered.apply(lambda x: x["gene_id"] if x["gene_name"]=="NA" else x["gene_name"], axis=1)

# %%
print(ensembl_filtered[ensembl_filtered["gene_name"]=="MALAT1"])
print(refseq_filtered[refseq_filtered["gene_name"]=="MALAT1"])
# Out:
#            chr         source     feature     start       end score strand  \
# 2407440  chr11         havana        gene  65497606  65508073     .      +
# 2407441  chr11  havana_tagene  transcript  65497606  65508073     .      +
# 2407442  chr11  havana_tagene        exon  65497606  65508073     .      +
# 2407443  chr11         havana  transcript  65497688  65499847     .      +
# 2407444  chr11         havana        exon  65497688  65497865     .      +
# ...        ...            ...         ...       ...       ...   ...    ...
# 2407710  chr11  havana_tagene        exon  65498969  65499966     .      +
# 2407711  chr11  havana_tagene  transcript  65503727  65504463     .      +
# 2407712  chr11  havana_tagene        exon  65503727  65503931     .      +
# 2407713  chr11  havana_tagene        exon  65504133  65504206     .      +
# 2407714  chr11  havana_tagene        exon  65504326  65504463     .      +
#
#         frame                                          attribute  \
# 2407440     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# 2407441     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# 2407442     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# 2407443     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# 2407444     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# ...       ...                                                ...
# 2407710     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# 2407711     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# 2407712     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# 2407713     .  gene_id "ENSG00000251562"; gene_version "12"; ...
# 2407714     .  gene_id "ENSG00000251562"; gene_version "12"; ...
#
#                                             attribute_dict gene_name  \
# 2407440  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# 2407441  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# 2407442  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# 2407443  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# 2407444  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# ...                                                    ...       ...
# 2407710  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# 2407711  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# 2407712  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# 2407713  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
# 2407714  {'gene_id': 'ENSG00000251562', 'gene_version':...    MALAT1
#
#            transcript_id          gene_id
# 2407440               NA  ENSG00000251562
# 2407441  ENST00000534336  ENSG00000251562
# 2407442  ENST00000534336  ENSG00000251562
# 2407443  ENST00000710927  ENSG00000251562
# 2407444  ENST00000710927  ENSG00000251562
# ...                  ...              ...
# 2407710  ENST00000783049  ENSG00000251562
# 2407711  ENST00000783050  ENSG00000251562
# 2407712  ENST00000783050  ENSG00000251562
# 2407713  ENST00000783050  ENSG00000251562
# 2407714  ENST00000783050  ENSG00000251562
#
# [275 rows x 13 columns]
#            chr      source     feature       start         end score strand  \
# 2526469  chr11  BestRefSeq        gene  65497738.0  65506516.0     .      +
# 2526470  chr11  BestRefSeq  transcript  65497738.0  65506516.0     .      +
# 2526471  chr11  BestRefSeq        exon  65497738.0  65498734.0     .      +
# 2526472  chr11  BestRefSeq        exon  65498969.0  65506516.0     .      +
# 2526473  chr11  BestRefSeq  transcript  65497738.0  65506516.0     .      +
# 2526474  chr11  BestRefSeq        exon  65497738.0  65498734.0     .      +
# 2526475  chr11  BestRefSeq        exon  65498969.0  65502393.0     .      +
# 2526476  chr11  BestRefSeq        exon  65502637.0  65506516.0     .      +
# 2526477  chr11  BestRefSeq  transcript  65499045.0  65506516.0     .      +
# 2526478  chr11  BestRefSeq        exon  65499045.0  65506516.0     .      +
#
#         frame                                          attribute  \
# 2526469     .  gene_id "MALAT1"; transcript_id ""; db_xref "G...
# 2526470     .  gene_id "MALAT1"; transcript_id "NR_144567.1";...
# 2526471     .  gene_id "MALAT1"; transcript_id "NR_144567.1";...
# 2526472     .  gene_id "MALAT1"; transcript_id "NR_144567.1";...
# 2526473     .  gene_id "MALAT1"; transcript_id "NR_144568.1";...
# 2526474     .  gene_id "MALAT1"; transcript_id "NR_144568.1";...
# 2526475     .  gene_id "MALAT1"; transcript_id "NR_144568.1";...
# 2526476     .  gene_id "MALAT1"; transcript_id "NR_144568.1";...
# 2526477     .  gene_id "MALAT1"; transcript_id "NR_002819.5";...
# 2526478     .  gene_id "MALAT1"; transcript_id "NR_002819.5";...
#
#                                             attribute_dict gene_name  \
# 2526469  {'gene_id': 'MALAT1', 'transcript_id': '', 'db...    MALAT1
# 2526470  {'gene_id': 'MALAT1', 'transcript_id': 'NR_144...    MALAT1
# 2526471  {'gene_id': 'MALAT1', 'transcript_id': 'NR_144...    MALAT1
# 2526472  {'gene_id': 'MALAT1', 'transcript_id': 'NR_144...    MALAT1
# 2526473  {'gene_id': 'MALAT1', 'transcript_id': 'NR_144...    MALAT1
# 2526474  {'gene_id': 'MALAT1', 'transcript_id': 'NR_144...    MALAT1
# 2526475  {'gene_id': 'MALAT1', 'transcript_id': 'NR_144...    MALAT1
# 2526476  {'gene_id': 'MALAT1', 'transcript_id': 'NR_144...    MALAT1
# 2526477  {'gene_id': 'MALAT1', 'transcript_id': 'NR_002...    MALAT1
# 2526478  {'gene_id': 'MALAT1', 'transcript_id': 'NR_002...    MALAT1
#
#         transcript_id gene_id
# 2526469                MALAT1
# 2526470   NR_144567.1  MALAT1
# 2526471   NR_144567.1  MALAT1
# 2526472   NR_144567.1  MALAT1
# 2526473   NR_144568.1  MALAT1
# 2526474   NR_144568.1  MALAT1
# 2526475   NR_144568.1  MALAT1
# 2526476   NR_144568.1  MALAT1
# 2526477   NR_002819.5  MALAT1
# 2526478   NR_002819.5  MALAT1

# %%
ensembl_filtered["coding"] = ensembl_filtered["attribute_dict"].apply(lambda x: "protein_coding" in x.get("gene_biotype", "NA"))

# %%
refseq_filtered = refseq_filtered[~(refseq_filtered["transcript_id"].str.startswith("unassigned"))].copy()
print(refseq_filtered)

# %%
refseq_filtered["coding"] = refseq_filtered["transcript_id"].str[1] == "M"
print(refseq_filtered)

# %%
print(ensembl_filtered["coding"].value_counts())
print(refseq_filtered["coding"].value_counts())
# Out:
# coding
# True     3083737
# False    1018409
# Name: count, dtype: int64
# coding
# True     3909153
# False     371394
# Name: count, dtype: int64

# %%
refseq_filtered[["start", "end"]] = refseq_filtered[["start", "end"]].astype(int)

# %%
def make_refflat(df):
    df = df[df["feature"].isin(["exon", "CDS"])]
    df = df.groupby("transcript_id")
    refflat_dict = {"transcript_id":[], "gene_id":[], "gene_name":[], "chr":[], "strand":[], "txStart":[], "txEnd":[], "cdsStart":[], "cdsEnd":[], "exonCount":[], "exonStarts":[], "exonEnds":[], "coding": []}
    for transcript_id, group in tqdm.tqdm(df, total=df.ngroups):
        refflat_dict["transcript_id"].append(transcript_id)
        refflat_dict["gene_id"].append(group["gene_id"].values[0])
        refflat_dict["gene_name"].append(group["gene_name"].values[0])
        refflat_dict["chr"].append(group["chr"].values[0])
        refflat_dict["strand"].append(group["strand"].values[0])
        start = group["start"].min()
        end = group["end"].max()
        refflat_dict["txStart"].append(start)
        refflat_dict["txEnd"].append(end)
        if group[group["feature"]=="CDS"].shape[0]==0:
            refflat_dict["cdsStart"].append(start)
            refflat_dict["cdsEnd"].append(end)
        else:
            refflat_dict["cdsStart"].append(group[group["feature"]=="CDS"]["start"].min())
            refflat_dict["cdsEnd"].append(group[group["feature"]=="CDS"]["end"].max())
        refflat_dict["coding"].append(group["coding"].any())
        refflat_dict["exonCount"].append(group[group["feature"]=="exon"].shape[0])
        refflat_dict["exonStarts"].append(",".join(group[group["feature"]=="exon"]["start"].sort_values().astype(str).values))
        refflat_dict["exonEnds"].append(",".join(group[group["feature"]=="exon"]["end"].sort_values().astype(str).values))
    refflat = pd.DataFrame(refflat_dict)
    return refflat

# %%
ensembl_refflat = make_refflat(ensembl_filtered)
# Out:
# 100%|█| 385622/385622 [15

# %%
refseq_refflat = make_refflat(refseq_filtered)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 177431/177431 [07:37<00:00, 388.25it/s]

# %%
refseq_refflat["source"] = "refseq"
ensembl_refflat["source"] = "ensembl"

# %%
ensembl_refflat.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/anno/ensembl_refflat.pkl")

# %%
refseq_refflat.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/anno/refseq_refflat.pkl")

# %%
print(ensembl_refflat)
# Out:
#           transcript_id          gene_id  gene_name    chr strand    txStart  \
# 0       ENST00000000233  ENSG00000004059       ARF5   chr7      +  127588411
# 1       ENST00000000412  ENSG00000003056       M6PR  chr12      -    8940361
# 2       ENST00000000442  ENSG00000173153      ESRRA  chr11      +   64305524
# 3       ENST00000001008  ENSG00000004478      FKBP4  chr12      +    2794970
# 4       ENST00000001146  ENSG00000003137    CYP26B1   chr2      -   72129238
# ...                 ...              ...        ...    ...    ...        ...
# 385617  ENST00000850839  ENSG00000310540  LINC02968   chrY      +    1661795
# 385618  ENST00000850840  ENSG00000292360  LINC03112   chrY      -    2566027
# 385619  ENST00000850841  ENSG00000292360  LINC03112   chrY      -    2566027
# 385620  ENST00000850842  ENSG00000292360  LINC03112   chrY      -    2566024
# 385621  ENST00000850843  ENSG00000292362     CD99P1   chrY      +    2609381
#
#             txEnd   cdsStart     cdsEnd  exonCount  \
# 0       127591700  127588499  127591296          6
# 1         8949645    8941821    8946404          7
# 2        64316743   64307180   64315963          7
# 3         2805423    2795140    2803255         10
# 4        72147862   72132230   72147834          6
# ...           ...        ...        ...        ...
# 385617    1662306    1661795    1662306          2
# 385618    2609183    2566027    2609183          4
# 385619    2609185    2566027    2609185          3
# 385620    2609205    2566024    2609205          3
# 385621    2658943    2609381    2658943         10
#
#                                                exonStarts  \
# 0       127588411,127589083,127589485,127590066,127590...
# 1       8940361,8942416,8943405,8943801,8945418,894622...
# 2       64305524,64307168,64313951,64314239,64314741,6...
# 3       2794970,2797138,2797729,2798706,2799088,279985...
# 4       72129238,72133023,72134761,72135144,72143989,7...
# ...                                                   ...
# 385617                                    1661795,1662161
# 385618                    2566027,2570011,2574096,2609106
# 385619                            2566027,2570011,2609106
# 385620                            2566024,2570011,2609106
# 385621  2609381,2610996,2612150,2615816,2618740,261942...
#
#                                                  exonEnds  coding   source
# 0       127588565,127589163,127589594,127590137,127591...    True  ensembl
# 1       8941940,8942542,8943535,8943910,8945584,894640...    True  ensembl
# 2       64305736,64307504,64314067,64314367,64314911,6...    True  ensembl
# 3       2795244,2797282,2797871,2798826,2799244,279994...    True  ensembl
# 4       72132619,72133307,72134916,72135419,72144213,7...    True  ensembl
# ...                                                   ...     ...      ...
# 385617                                    1662052,1662306   False  ensembl
# 385618                    2567292,2570098,2574289,2609183   False  ensembl
# 385619                            2567292,2570098,2609185   False  ensembl
# 385620                            2567292,2570166,2609205   False  ensembl
# 385621  2609481,2611038,2612218,2615969,2618784,261949...   False  ensembl
#
# [385622 rows x 14 columns]

# %%
print(refseq_refflat)
# Out:
#        transcript_id       gene_id     gene_name    chr strand    txStart  \
# 0        NM_000014.6           A2M           A2M  chr12      -    9067708
# 1        NM_000015.3          NAT2          NAT2   chr8      +   18391282
# 2        NM_000016.6         ACADM         ACADM   chr1      +   75724709
# 3        NM_000017.4         ACADS         ACADS  chr12      +  120725826
# 4        NM_000018.4        ACADVL        ACADVL  chr17      +    7219938
# ...              ...           ...           ...    ...    ...        ...
# 177426   XR_951226.3  LOC105372853  LOC105372853  chr22      +   18057028
# 177427   XR_951228.1  LOC105379518  LOC105379518  chr22      +   18233149
# 177428   XR_951230.2       FAM247D       FAM247D  chr22      +   18349976
# 177429   XR_951236.3      TMEM191B      TMEM191B  chr22      +   18527802
# 177430   XR_951292.2     LINC02968     LINC02968   chrX      +    1732556
#
#             txEnd   cdsStart     cdsEnd  exonCount  \
# 0         9115919    9067826    9115849         36
# 1        18401218   18400004   18400873          2
# 2        75763679   75724788   75762760         12
# 3       120740008  120725886  120739445         10
# 4         7225266    7219985    7225094         20
# ...           ...        ...        ...        ...
# 177426   18077896   18057028   18077896          8
# 177427   18235228   18233149   18235228          3
# 177428   18361189   18349976   18361189          2
# 177429   18530182   18527802   18530182          8
# 177430    1755984    1732556    1755984          8
#
#                                                exonStarts  \
# 0       9067708,9068183,9068740,9069745,9070488,907235...
# 1                                       18391282,18399998
# 2       75724709,75728401,75732644,75732853,75733528,7...
# 3       120725826,120727026,120736986,120737356,120737...
# 4       7219938,7220122,7220464,7220604,7220766,722092...
# ...                                                   ...
# 177426  18057028,18060706,18070158,18070384,18070767,1...
# 177427                         18233149,18234596,18235170
# 177428                                  18349976,18360564
# 177429  18527802,18528559,18528817,18529019,18529441,1...
# 177430  1732556,1733950,1741931,1743588,1743787,174729...
#
#                                                  exonEnds  coding  source
# 0       9067839,9068224,9068842,9069813,9070578,907248...    True  refseq
# 1                                       18391345,18401218    True  refseq
# 2       75724817,75728488,75732741,75732922,75733628,7...    True  refseq
# 3       120725931,120727189,120737135,120737467,120737...    True  refseq
# 4       7220046,7220197,7220529,7220676,7220830,722105...    True  refseq
# ...                                                   ...     ...     ...
# 177426  18057120,18060926,18070213,18070501,18070822,1...   False  refseq
# 177427                         18233744,18234654,18235228   False  refseq
# 177428                                  18350514,18361189   False  refseq
# 177429  18528276,18528682,18528867,18529093,18529497,1...   False  refseq
# 177430  1732723,1734196,1742026,1743693,1744574,174754...   False  refseq
#
# [177431 rows x 14 columns]

# %%
ensembl_refflat_grouped = ensembl_refflat.groupby(["chr", "strand"])
ensembl_refflat_grouped = {key: value for key, value in ensembl_refflat_grouped}
refseq_refflat_grouped = refseq_refflat.groupby(["chr", "strand"])
refseq_refflat_grouped = {key: value for key, value in refseq_refflat_grouped}

# %%
assert (ensembl_refflat_grouped.keys() == refseq_refflat_grouped.keys())

# %%
merged_refflat = []

for key in tqdm.tqdm(ensembl_refflat_grouped.keys()):
    ensembl = ensembl_refflat_grouped[key]
    refseq = refseq_refflat_grouped[key]
    ## Merge and remove duplicates
    merged = pd.concat([ensembl, refseq], axis=0)
    merged = merged.drop_duplicates(subset=["exonStarts", "exonEnds"], keep="first")
    merged_refflat.append(merged)

merged_refflat = pd.concat(merged_refflat, axis=0)

print(merged_refflat)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:01<00:00, 47.36it/s]
#           transcript_id          gene_id     gene_name   chr strand  \
# 14      ENST00000003912  ENSG00000001461        NIPAL3  chr1      +
# 53      ENST00000008440  ENSG00000010072         SPRTN  chr1      +
# 58      ENST00000009105  ENSG00000008118        CAMK1G  chr1      +
# 63      ENST00000010299  ENSG00000009780        FAM76A  chr1      +
# 71      ENST00000011700  ENSG00000048707        VPS13D  chr1      +
# ...                 ...              ...           ...   ...    ...
# 174741      XR_938669.2     LOC105377241  LOC105377241  chrY      -
# 174742      XR_938670.2     LOC105377241  LOC105377241  chrY      -
# 174745      XR_938673.3          REREP2Y       REREP2Y  chrY      -
# 174746      XR_938675.3     LOC105377244  LOC105377244  chrY      -
# 177350      XR_950583.3      LINC03112_1   LINC03112_1  chrY      -
#
#           txStart      txEnd   cdsStart     cdsEnd  exonCount  \
# 14       24415803   24475252   24442139   24469182         13
# 53      231338256  231352521  231338384  231351603          3
# 58      209583717  209613938  209594984  209612872         13
# 63       27726057   27760581   27726081   27760578         10
# 71       12277121   12510361   12277121   12509021         52
# ...           ...        ...        ...        ...        ...
# 174741   24740119   24743460   24740119   24743460          3
# 174742   24740119   24743460   24740119   24743460          3
# 174745   26193868   26235374   26193868   26235374          3
# 174746   26401148   26409142   26401148   26409142          3
# 177350    2566029    2574633    2566029    2574633          3
#
#                                                exonStarts  \
# 14      24415803,24419291,24433104,24440172,24442055,2...
# 53                          231338256,231339769,231351304
# 58      209583717,209594955,209599983,209603214,209605...
# 63      27726057,27727472,27730232,27732603,27734031,2...
# 71      12277121,12279499,12282705,12288223,12290998,1...
# ...                                                   ...
# 174741                         24740119,24742551,24743278
# 174742                         24740119,24742578,24743278
# 174745                         26193868,26208076,26234972
# 174746                         26401148,26406617,26408912
# 177350                            2566029,2570011,2574113
#
#                                                  exonEnds  coding   source
# 14      24415904,24419640,24433213,24440240,24442226,2...    True  ensembl
# 53                          231338604,231339868,231352521    True  ensembl
# 58      209583932,209595075,209600111,209603288,209605...    True  ensembl
# 63      27726161,27727536,27730333,27732657,27734183,2...    True  ensembl
# 71      12278038,12279650,12283736,12288313,12291124,1...    True  ensembl
# ...                                                   ...     ...      ...
# 174741                         24740219,24742615,24743460   False   refseq
# 174742                         24740219,24742615,24743460   False   refseq
# 174745                         26198457,26208148,26235374   False   refseq
# 174746                         26405750,26406783,26409142   False   refseq
# 177350                            2567292,2570166,2574633   False   refseq
#
# [537999 rows x 14 columns]

# %%
merged_refflat.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/anno/merged_refflat.pkl")

# %%
print(len(ensembl_refflat), len(refseq_refflat), len(merged_refflat))
# Out:
# 385622 177431 537999

# %%
print(merged_refflat[merged_refflat["source"]=="ensembl"])
print(merged_refflat[merged_refflat["source"]=="refseq"])
# Out:
#           transcript_id          gene_id  gene_name   chr strand    txStart  \
# 14      ENST00000003912  ENSG00000001461     NIPAL3  chr1      +   24415803
# 53      ENST00000008440  ENSG00000010072      SPRTN  chr1      +  231338256
# 58      ENST00000009105  ENSG00000008118     CAMK1G  chr1      +  209583717
# 63      ENST00000010299  ENSG00000009780     FAM76A  chr1      +   27726057
# 71      ENST00000011700  ENSG00000048707     VPS13D  chr1      +   12277121
# ...                 ...              ...        ...   ...    ...        ...
# 385615  ENST00000850837  ENSG00000292360  LINC03112  chrY      -    2566025
# 385616  ENST00000850838  ENSG00000292360  LINC03112  chrY      -    2566027
# 385618  ENST00000850840  ENSG00000292360  LINC03112  chrY      -    2566027
# 385619  ENST00000850841  ENSG00000292360  LINC03112  chrY      -    2566027
# 385620  ENST00000850842  ENSG00000292360  LINC03112  chrY      -    2566024
#
#             txEnd   cdsStart     cdsEnd  exonCount  \
# 14       24475252   24442139   24469182         13
# 53      231352521  231338384  231351603          3
# 58      209613938  209594984  209612872         13
# 63       27760581   27726081   27760578         10
# 71       12510361   12277121   12509021         52
# ...           ...        ...        ...        ...
# 385615    2609211    2566025    2609211          4
# 385616    2609189    2566027    2609189          4
# 385618    2609183    2566027    2609183          4
# 385619    2609185    2566027    2609185          3
# 385620    2609205    2566024    2609205          3
#
#                                                exonStarts  \
# 14      24415803,24419291,24433104,24440172,24442055,2...
# 53                          231338256,231339769,231351304
# 58      209583717,209594955,209599983,209603214,209605...
# 63      27726057,27727472,27730232,27732603,27734031,2...
# 71      12277121,12279499,12282705,12288223,12290998,1...
# ...                                                   ...
# 385615                    2566025,2570011,2574096,2609106
# 385616                    2566027,2570011,2574113,2609106
# 385618                    2566027,2570011,2574096,2609106
# 385619                            2566027,2570011,2609106
# 385620                            2566024,2570011,2609106
#
#                                                  exonEnds  coding   source
# 14      24415904,24419640,24433213,24440240,24442226,2...    True  ensembl
# 53                          231338604,231339868,231352521    True  ensembl
# 58      209583932,209595075,209600111,209603288,209605...    True  ensembl
# 63      27726161,27727536,27730333,27732657,27734183,2...    True  ensembl
# 71      12278038,12279650,12283736,12288313,12291124,1...    True  ensembl
# ...                                                   ...     ...      ...
# 385615                    2567292,2570166,2574289,2609211   False  ensembl
# 385616                    2567292,2570166,2574289,2609189   False  ensembl
# 385618                    2567292,2570098,2574289,2609183   False  ensembl
# 385619                            2567292,2570098,2609185   False  ensembl
# 385620                            2567292,2570166,2609205   False  ensembl
#
# [385465 rows x 14 columns]
#        transcript_id       gene_id     gene_name   chr strand    txStart  \
# 14       NM_000028.3           AGL           AGL  chr1      +   99850621
# 274      NM_000299.4          PKP1          PKP1  chr1      +  201283506
# 284      NM_000309.5          PPOX          PPOX  chr1      +  161166426
# 596      NM_000643.3           AGL           AGL  chr1      +   99850361
# 597      NM_000644.3           AGL           AGL  chr1      +   99850361
# ...              ...           ...           ...   ...    ...        ...
# 174741   XR_938669.2  LOC105377241  LOC105377241  chrY      -   24740119
# 174742   XR_938670.2  LOC105377241  LOC105377241  chrY      -   24740119
# 174745   XR_938673.3       REREP2Y       REREP2Y  chrY      -   26193868
# 174746   XR_938675.3  LOC105377244  LOC105377244  chrY      -   26401148
# 177350   XR_950583.3   LINC03112_1   LINC03112_1  chrY      -    2566029
#
#             txEnd   cdsStart     cdsEnd  exonCount  \
# 14       99924020   99851043   99921648         34
# 274     201332989  201283703  201328833         15
# 284     161171220  161166848  161171173         13
# 596      99924020   99851043   99921648         34
# 597      99924020   99851043   99921648         34
# ...           ...        ...        ...        ...
# 174741   24743460   24740119   24743460          3
# 174742   24743460   24740119   24743460          3
# 174745   26235374   26193868   26235374          3
# 174746   26409142   26401148   26409142          3
# 177350    2574633    2566029    2574633          3
#
#                                                exonStarts  \
# 14      99850621,99850975,99861503,99862257,99864386,9...
# 274     201283506,201293942,201313166,201316553,201317...
# 284     161166426,161166840,161167100,161167371,161167...
# 596     99850361,99850975,99861503,99862257,99864386,9...
# 597     99850361,99851035,99861503,99862257,99864386,9...
# ...                                                   ...
# 174741                         24740119,24742551,24743278
# 174742                         24740119,24742578,24743278
# 174745                         26193868,26208076,26234972
# 174746                         26401148,26406617,26408912
# 177350                            2566029,2570011,2574113
#
#                                                  exonEnds  coding  source
# 14      99850898,99851124,99861713,99862423,99864589,9...    True  refseq
# 274     201283904,201294045,201313560,201316697,201317...    True  refseq
# 284     161166611,161166934,161167234,161167486,161168...    True  refseq
# 596     99850618,99851124,99861713,99862423,99864589,9...    True  refseq
# 597     99850618,99851124,99861713,99862423,99864589,9...    True  refseq
# ...                                                   ...     ...     ...
# 174741                         24740219,24742615,24743460   False  refseq
# 174742                         24740219,24742615,24743460   False  refseq
# 174745                         26198457,26208148,26235374   False  refseq
# 174746                         26405750,26406783,26409142   False  refseq
# 177350                            2567292,2570166,2574633   False  refseq
#
# [152534 rows x 14 columns]

# %%
merged_refflat_groupby_gene = merged_refflat.groupby("gene_name")
merged_refflat_groupby_gene = {key: value for key, value in merged_refflat_groupby_gene}
# Out:
# gene_id
# 1      70425
# 2      20101
# 3        326
# 4          7
# 7          4
# 8          3
# 6          2
# 9          1
# 5          1
# 170        1
# 27         1
# 19         1
# 50         1
# 33         1
# 22         1
# 756        1
# Name: count, dtype: int64

# %%
passed = []
failed = []

for gene_name, group in tqdm.tqdm(merged_refflat_groupby_gene):
    unique_id = group["gene_id"].unique()
    if group["source"].nunique()==1:
        passed.append(group)
    else:
        if len(unique_id)==1:
            passed.append(group)
        elif len(unique_id)==2:
            group = group.copy()
            ensembl_id = group[group["source"]=="ensembl"]["gene_id"].values[0]
            group["gene_id"] = ensembl_id
            passed.append(group)
        else:
            failed.append(group)

print(len(passed), len(failed))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 90877/90877 [00:43<00:00, 2099.28it/s]
# 90548 329

# %%
merged_refflat_v2 = pd.concat(passed+failed, axis=0)
print(merged_refflat_v2)
# Out:
#           transcript_id          gene_id gene_name    chr strand    txStart  \
# 200050  ENST00000648701  ENSG00000285609   5S_rRNA   chr1      -  182944365
# 223894  ENST00000674448  ENSG00000288601   5S_rRNA  chr16      -   47450347
# 183361  ENST00000618379  ENSG00000277488   5S_rRNA  chr17      -   37940704
# 200151  ENST00000648813  ENSG00000285674   5S_rRNA  chr19      -    7886977
# 180164  ENST00000612131  ENSG00000276861   5S_rRNA   chr2      +   89600571
# ...                 ...              ...       ...    ...    ...        ...
# 357059  ENST00000821490  ENSG00000293494    ZPLD2P   chr1      +   26225438
# 357060  ENST00000821491  ENSG00000293494    ZPLD2P   chr1      +   26225087
# 357061  ENST00000821492  ENSG00000293494    ZPLD2P   chr1      +   26225315
# 357062  ENST00000821493  ENSG00000293494    ZPLD2P   chr1      +   26225320
# 76242       NR_110698.1           ZPLD2P    ZPLD2P   chr1      +   26225320
#
#             txEnd   cdsStart     cdsEnd  exonCount  \
# 200050  182944490  182944365  182944490          1
# 223894   47450461   47450347   47450461          1
# 183361   37940790   37940704   37940790          1
# 200151    7887096    7886977    7887096          1
# 180164   89600680   89600571   89600680          1
# ...           ...        ...        ...        ...
# 357059   26229844   26225438   26229844          4
# 357060   26228145   26225087   26228145          3
# 357061   26228145   26225315   26228145          4
# 357062   26228145   26225320   26228145          3
# 76242    26229840   26225320   26229840          4
#
#                                  exonStarts  \
# 200050                            182944365
# 223894                             47450347
# 183361                             37940704
# 200151                              7886977
# 180164                             89600571
# ...                                     ...
# 357059  26225438,26227404,26227794,26229502
# 357060           26225087,26225593,26227794
# 357061  26225315,26225593,26227404,26227794
# 357062           26225320,26227404,26227794
# 76242   26225320,26227404,26227794,26229502
#
#                                    exonEnds  coding   source
# 200050                            182944490   False  ensembl
# 223894                             47450461   False  ensembl
# 183361                             37940790   False  ensembl
# 200151                              7887096   False  ensembl
# 180164                             89600680   False  ensembl
# ...                                     ...     ...      ...
# 357059  26226155,26227555,26227996,26229844   False  ensembl
# 357060           26225263,26225703,26228145   False  ensembl
# 357061  26225488,26225703,26227555,26228145   False  ensembl
# 357062           26225703,26227568,26228145   False  ensembl
# 76242   26225703,26227555,26227996,26229840   False   refseq
#
# [537999 rows x 14 columns]

# %%
merged_refflat_v2 = merged_refflat_v2.reset_index(drop=True)
merged_refflat_v2.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/anno/merged_refflat_v2.pkl")

# %%
refflat_columns = ["gene_name", "transcript_id", "chr", "strand", "txStart", "txEnd", "cdsStart", "cdsEnd", "exonCount", "exonStarts", "exonEnds"]
refflat_for_record = merged_refflat_v2[refflat_columns].copy()
refflat_for_record.to_csv("/extdata4/baeklab/Hyeonseo/m6A/anno/refflat_for_record.txt", sep="\t", index=False, header=False)

# %%
print(refseq_filtered)
# Out:
#           chr      source     feature     start       end score strand frame  \
# 0        chr1  BestRefSeq        gene     11874     14409     .      +     .
# 1        chr1  BestRefSeq  transcript     11874     14409     .      +     .
# 2        chr1  BestRefSeq        exon     11874     12227     .      +     .
# 3        chr1  BestRefSeq        exon     12613     12721     .      +     .
# 4        chr1  BestRefSeq        exon     13221     14409     .      +     .
# ...       ...         ...         ...       ...       ...   ...    ...   ...
# 4290478  chrY  BestRefSeq        gene  57212178  57214703     .      -     .
# 4290479  chrY  BestRefSeq  transcript  57212178  57214703     .      -     .
# 4290480  chrY  BestRefSeq        exon  57214350  57214703     .      -     .
# 4290481  chrY  BestRefSeq        exon  57213856  57213964     .      -     .
# 4290482  chrY  BestRefSeq        exon  57212178  57213357     .      -     .
#
#                                                  attribute  \
# 0        gene_id "DDX11L1"; transcript_id ""; db_xref "...
# 1        gene_id "DDX11L1"; transcript_id "NR_046018.2"...
# 2        gene_id "DDX11L1"; transcript_id "NR_046018.2"...
# 3        gene_id "DDX11L1"; transcript_id "NR_046018.2"...
# 4        gene_id "DDX11L1"; transcript_id "NR_046018.2"...
# ...                                                    ...
# 4290478  gene_id "DDX11L16_1"; transcript_id ""; db_xre...
# 4290479  gene_id "DDX11L16_1"; transcript_id "NR_110561...
# 4290480  gene_id "DDX11L16_1"; transcript_id "NR_110561...
# 4290481  gene_id "DDX11L16_1"; transcript_id "NR_110561...
# 4290482  gene_id "DDX11L16_1"; transcript_id "NR_110561...
#
#                                             attribute_dict   gene_name  \
# 0        {'gene_id': 'DDX11L1', 'transcript_id': '', 'd...     DDX11L1
# 1        {'gene_id': 'DDX11L1', 'transcript_id': 'NR_04...     DDX11L1
# 2        {'gene_id': 'DDX11L1', 'transcript_id': 'NR_04...     DDX11L1
# 3        {'gene_id': 'DDX11L1', 'transcript_id': 'NR_04...     DDX11L1
# 4        {'gene_id': 'DDX11L1', 'transcript_id': 'NR_04...     DDX11L1
# ...                                                    ...         ...
# 4290478  {'gene_id': 'DDX11L16_1', 'transcript_id': '',...  DDX11L16_1
# 4290479  {'gene_id': 'DDX11L16_1', 'transcript_id': 'NR...  DDX11L16_1
# 4290480  {'gene_id': 'DDX11L16_1', 'transcript_id': 'NR...  DDX11L16_1
# 4290481  {'gene_id': 'DDX11L16_1', 'transcript_id': 'NR...  DDX11L16_1
# 4290482  {'gene_id': 'DDX11L16_1', 'transcript_id': 'NR...  DDX11L16_1
#
#          transcript_id     gene_id  coding
# 0                          DDX11L1   False
# 1          NR_046018.2     DDX11L1   False
# 2          NR_046018.2     DDX11L1   False
# 3          NR_046018.2     DDX11L1   False
# 4          NR_046018.2     DDX11L1   False
# ...                ...         ...     ...
# 4290478                 DDX11L16_1   False
# 4290479  NR_110561.1_1  DDX11L16_1   False
# 4290480  NR_110561.1_1  DDX11L16_1   False
# 4290481  NR_110561.1_1  DDX11L16_1   False
# 4290482  NR_110561.1_1  DDX11L16_1   False
#
# [4280547 rows x 14 columns]

# %%
print(ensembl_filtered)
# Out:
#            chr          source      feature    start      end score strand  \
# 0         chr1  ensembl_havana         gene  3069168  3438621     .      +
# 1         chr1          havana   transcript  3069168  3434342     .      +
# 2         chr1          havana         exon  3069168  3069296     .      +
# 3         chr1          havana          CDS  3069260  3069296     .      +
# 4         chr1          havana  start_codon  3069260  3069262     .      +
# ...        ...             ...          ...      ...      ...   ...    ...
# 4102141  chr21   havana_tagene         exon  9678230  9678353     .      +
# 4102142  chr21   havana_tagene         exon  9679515  9679891     .      +
# 4102143  chr21   havana_tagene   transcript  9662173  9677705     .      +
# 4102144  chr21   havana_tagene         exon  9662173  9662338     .      +
# 4102145  chr21   havana_tagene         exon  9677372  9677705     .      +
#
#         frame                                          attribute  \
# 0           .  gene_id "ENSG00000142611"; gene_version "17"; ...
# 1           .  gene_id "ENSG00000142611"; gene_version "17"; ...
# 2           .  gene_id "ENSG00000142611"; gene_version "17"; ...
# 3           0  gene_id "ENSG00000142611"; gene_version "17"; ...
# 4           0  gene_id "ENSG00000142611"; gene_version "17"; ...
# ...       ...                                                ...
# 4102141     .  gene_id "ENSG00000293062"; gene_version "2"; t...
# 4102142     .  gene_id "ENSG00000293062"; gene_version "2"; t...
# 4102143     .  gene_id "ENSG00000293062"; gene_version "2"; t...
# 4102144     .  gene_id "ENSG00000293062"; gene_version "2"; t...
# 4102145     .  gene_id "ENSG00000293062"; gene_version "2"; t...
#
#                                             attribute_dict        gene_name  \
# 0        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# 1        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# 2        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# 3        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# 4        {'gene_id': 'ENSG00000142611', 'gene_version':...           PRDM16
# ...                                                    ...              ...
# 4102141  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
# 4102142  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
# 4102143  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
# 4102144  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
# 4102145  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
#
#            transcript_id          gene_id  coding
# 0                     NA  ENSG00000142611    True
# 1        ENST00000511072  ENSG00000142611    True
# 2        ENST00000511072  ENSG00000142611    True
# 3        ENST00000511072  ENSG00000142611    True
# 4        ENST00000511072  ENSG00000142611    True
# ...                  ...              ...     ...
# 4102141  ENST00000842019  ENSG00000293062   False
# 4102142  ENST00000842019  ENSG00000293062   False
# 4102143  ENST00000842020  ENSG00000293062   False
# 4102144  ENST00000842020  ENSG00000293062   False
# 4102145  ENST00000842020  ENSG00000293062   False
#
# [4102146 rows x 14 columns]

# %%
ensembl_transcript_unique_refflat = merged_refflat_v2[merged_refflat_v2["source"]=="ensembl"]["transcript_id"].unique()
refseq_transcript_unique_refflat = merged_refflat_v2[merged_refflat_v2["source"]=="refseq"]["transcript_id"].unique()
print(len(ensembl_transcript_unique_refflat), len(refseq_transcript_unique_refflat))
# Out:
# 385465 152534

# %%
ensembl_filtered_transcript = []
refseq_filtered_transcript = []

ensembl_filtered_grouped = ensembl_filtered.groupby("transcript_id")
refseq_filtered_grouped = refseq_filtered.groupby("transcript_id")

for transcript_id in tqdm.tqdm(ensembl_transcript_unique_refflat):
    ensembl_filtered_transcript.append(ensembl_filtered_grouped.get_group(transcript_id))

for transcript_id in tqdm.tqdm(refseq_transcript_unique_refflat):
    refseq_filtered_transcript.append(refseq_filtered_grouped.get_group(transcript_id))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 385465/385465 [02:01<00:00, 3174.81it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 152534/152534 [00:29<00:00, 5196.54it/s]

# %%
transcript_to_gene_dict = dict(zip(merged_refflat_v2["transcript_id"], merged_refflat_v2["gene_id"]))

# %%
merged_gtf = pd.concat(ensembl_filtered_transcript+refseq_filtered_transcript, axis=0)
merged_gtf["new_gene_id"] = merged_gtf["transcript_id"].apply(lambda x: transcript_to_gene_dict[x])
print(merged_gtf)
# Out:
#            chr      source     feature      start        end score strand  \
# 36503     chr1     ensembl  transcript  182944365  182944490     .      -
# 36504     chr1     ensembl        exon  182944365  182944490     .      -
# 3272176  chr16     ensembl  transcript   47450347   47450461     .      -
# 3272177  chr16     ensembl        exon   47450347   47450461     .      -
# 3420710  chr17     ensembl  transcript   37940704   37940790     .      -
# ...        ...         ...         ...        ...        ...   ...    ...
# 88849     chr1  BestRefSeq  transcript   26225320   26229840     .      +
# 88850     chr1  BestRefSeq        exon   26225320   26225703     .      +
# 88851     chr1  BestRefSeq        exon   26227404   26227555     .      +
# 88852     chr1  BestRefSeq        exon   26227794   26227996     .      +
# 88853     chr1  BestRefSeq        exon   26229502   26229840     .      +
#
#         frame                                          attribute  \
# 36503       .  gene_id "ENSG00000285609"; gene_version "1"; t...
# 36504       .  gene_id "ENSG00000285609"; gene_version "1"; t...
# 3272176     .  gene_id "ENSG00000288601"; gene_version "1"; t...
# 3272177     .  gene_id "ENSG00000288601"; gene_version "1"; t...
# 3420710     .  gene_id "ENSG00000277488"; gene_version "1"; t...
# ...       ...                                                ...
# 88849       .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 88850       .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 88851       .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 88852       .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 88853       .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
#
#                                             attribute_dict gene_name  \
# 36503    {'gene_id': 'ENSG00000285609', 'gene_version':...   5S_rRNA
# 36504    {'gene_id': 'ENSG00000285609', 'gene_version':...   5S_rRNA
# 3272176  {'gene_id': 'ENSG00000288601', 'gene_version':...   5S_rRNA
# 3272177  {'gene_id': 'ENSG00000288601', 'gene_version':...   5S_rRNA
# 3420710  {'gene_id': 'ENSG00000277488', 'gene_version':...   5S_rRNA
# ...                                                    ...       ...
# 88849    {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 88850    {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 88851    {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 88852    {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 88853    {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
#
#            transcript_id          gene_id  coding      new_gene_id
# 36503    ENST00000648701  ENSG00000285609   False  ENSG00000285609
# 36504    ENST00000648701  ENSG00000285609   False  ENSG00000285609
# 3272176  ENST00000674448  ENSG00000288601   False  ENSG00000288601
# 3272177  ENST00000674448  ENSG00000288601   False  ENSG00000288601
# 3420710  ENST00000618379  ENSG00000277488   False  ENSG00000277488
# ...                  ...              ...     ...              ...
# 88849        NR_110698.1           ZPLD2P   False           ZPLD2P
# 88850        NR_110698.1           ZPLD2P   False           ZPLD2P
# 88851        NR_110698.1           ZPLD2P   False           ZPLD2P
# 88852        NR_110698.1           ZPLD2P   False           ZPLD2P
# 88853        NR_110698.1           ZPLD2P   False           ZPLD2P
#
# [7735349 rows x 15 columns]

# %%
merged_gtf = merged_gtf.reset_index(drop=True)
print(merged_gtf)
# Out:
#            chr      source     feature      start        end score strand  \
# 0         chr1     ensembl  transcript  182944365  182944490     .      -
# 1         chr1     ensembl        exon  182944365  182944490     .      -
# 2        chr16     ensembl  transcript   47450347   47450461     .      -
# 3        chr16     ensembl        exon   47450347   47450461     .      -
# 4        chr17     ensembl  transcript   37940704   37940790     .      -
# ...        ...         ...         ...        ...        ...   ...    ...
# 7735344   chr1  BestRefSeq  transcript   26225320   26229840     .      +
# 7735345   chr1  BestRefSeq        exon   26225320   26225703     .      +
# 7735346   chr1  BestRefSeq        exon   26227404   26227555     .      +
# 7735347   chr1  BestRefSeq        exon   26227794   26227996     .      +
# 7735348   chr1  BestRefSeq        exon   26229502   26229840     .      +
#
#         frame                                          attribute  \
# 0           .  gene_id "ENSG00000285609"; gene_version "1"; t...
# 1           .  gene_id "ENSG00000285609"; gene_version "1"; t...
# 2           .  gene_id "ENSG00000288601"; gene_version "1"; t...
# 3           .  gene_id "ENSG00000288601"; gene_version "1"; t...
# 4           .  gene_id "ENSG00000277488"; gene_version "1"; t...
# ...       ...                                                ...
# 7735344     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735345     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735346     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735347     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735348     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
#
#                                             attribute_dict gene_name  \
# 0        {'gene_id': 'ENSG00000285609', 'gene_version':...   5S_rRNA
# 1        {'gene_id': 'ENSG00000285609', 'gene_version':...   5S_rRNA
# 2        {'gene_id': 'ENSG00000288601', 'gene_version':...   5S_rRNA
# 3        {'gene_id': 'ENSG00000288601', 'gene_version':...   5S_rRNA
# 4        {'gene_id': 'ENSG00000277488', 'gene_version':...   5S_rRNA
# ...                                                    ...       ...
# 7735344  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 7735345  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 7735346  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 7735347  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 7735348  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
#
#            transcript_id          gene_id  coding      new_gene_id
# 0        ENST00000648701  ENSG00000285609   False  ENSG00000285609
# 1        ENST00000648701  ENSG00000285609   False  ENSG00000285609
# 2        ENST00000674448  ENSG00000288601   False  ENSG00000288601
# 3        ENST00000674448  ENSG00000288601   False  ENSG00000288601
# 4        ENST00000618379  ENSG00000277488   False  ENSG00000277488
# ...                  ...              ...     ...              ...
# 7735344      NR_110698.1           ZPLD2P   False           ZPLD2P
# 7735345      NR_110698.1           ZPLD2P   False           ZPLD2P
# 7735346      NR_110698.1           ZPLD2P   False           ZPLD2P
# 7735347      NR_110698.1           ZPLD2P   False           ZPLD2P
# 7735348      NR_110698.1           ZPLD2P   False           ZPLD2P
#
# [7735349 rows x 15 columns]

# %%
## update attribute_dict to have new gene_id

def update_attribute_dict(attribute_dict, gene_id):
    attribute_dict["gene_id"] = gene_id
    return attribute_dict

# %%
merged_gtf["attribute_dict"] = merged_gtf.apply(lambda x: update_attribute_dict(x["attribute_dict"], x["new_gene_id"]), axis=1)

# %%
gene_gtf_df = pd.concat([refseq_filtered[refseq_filtered["feature"]=="gene"], ensembl_filtered[ensembl_filtered["feature"]=="gene"]], axis=0)
print(gene_gtf_df)
# Out:
#            chr      source feature     start       end score strand frame  \
# 0         chr1  BestRefSeq    gene     11874     14409     .      +     .
# 5         chr1  BestRefSeq    gene     14362     29370     .      -     .
# 18        chr1  BestRefSeq    gene     17369     17436     .      -     .
# 25        chr1      Gnomon    gene     29774     35418     .      +     .
# 30        chr1  BestRefSeq    gene     30366     30503     .      +     .
# ...        ...         ...     ...       ...       ...   ...    ...   ...
# 4101459  chr21      havana    gene  34412200  34412587     .      +     .
# 4101462  chr21      havana    gene  34414494  34423951     .      -     .
# 4101483  chr21      havana    gene  34425508  34426017     .      +     .
# 4101486  chr21      havana    gene   6630182   6670761     .      -     .
# 4102077  chr21      havana    gene   9529928   9679906     .      +     .
#
#                                                  attribute  \
# 0        gene_id "DDX11L1"; transcript_id ""; db_xref "...
# 5        gene_id "WASH7P"; transcript_id ""; db_xref "G...
# 18       gene_id "MIR6859-1"; transcript_id ""; db_xref...
# 25       gene_id "MIR1302-2HG"; transcript_id ""; db_xr...
# 30       gene_id "MIR1302-2"; transcript_id ""; db_xref...
# ...                                                    ...
# 4101459  gene_id "ENSG00000273104"; gene_version "1"; g...
# 4101462  gene_id "ENSG00000243627"; gene_version "6"; g...
# 4101483  gene_id "ENSG00000272958"; gene_version "1"; g...
# 4101486  gene_id "ENSG00000280145"; gene_version "4"; g...
# 4102077  gene_id "ENSG00000293062"; gene_version "2"; g...
#
#                                             attribute_dict        gene_name  \
# 0        {'gene_id': 'DDX11L1', 'transcript_id': '', 'd...          DDX11L1
# 5        {'gene_id': 'WASH7P', 'transcript_id': '', 'db...           WASH7P
# 18       {'gene_id': 'MIR6859-1', 'transcript_id': '', ...        MIR6859-1
# 25       {'gene_id': 'MIR1302-2HG', 'transcript_id': ''...      MIR1302-2HG
# 30       {'gene_id': 'MIR1302-2', 'transcript_id': '', ...        MIR1302-2
# ...                                                    ...              ...
# 4101459  {'gene_id': 'ENSG00000273104', 'gene_version':...  ENSG00000273104
# 4101462  {'gene_id': 'ENSG00000243627', 'gene_version':...           SMIM34
# 4101483  {'gene_id': 'ENSG00000272958', 'gene_version':...  ENSG00000272958
# 4101486  {'gene_id': 'ENSG00000280145', 'gene_version':...  ENSG00000280145
# 4102077  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
#
#         transcript_id          gene_id  coding
# 0                              DDX11L1   False
# 5                               WASH7P   False
# 18                           MIR6859-1   False
# 25                         MIR1302-2HG   False
# 30                           MIR1302-2   False
# ...               ...              ...     ...
# 4101459            NA  ENSG00000273104   False
# 4101462            NA  ENSG00000243627    True
# 4101483            NA  ENSG00000272958   False
# 4101486            NA  ENSG00000280145   False
# 4102077            NA  ENSG00000293062   False
#
# [137617 rows x 14 columns]

# %%
gene_gtf_df
# Out:
#           chr      source feature     start       end score strand frame  \
# 0        chr1  BestRefSeq    gene     11874     14409     .      +     .
# 1        chr1  BestRefSeq    gene     14362     29370     .      -     .
# 2        chr1  BestRefSeq    gene     17369     17436     .      -     .
# 3        chr1      Gnomon    gene     29774     35418     .      +     .
# 4        chr1  BestRefSeq    gene     30366     30503     .      +     .
# ...       ...         ...     ...       ...       ...   ...    ...   ...
# 137612  chr21      havana    gene  34412200  34412587     .      +     .
# 137613  chr21      havana    gene  34414494  34423951     .      -     .
# 137614  chr21      havana    gene  34425508  34426017     .      +     .
# 137615  chr21      havana    gene   6630182   6670761     .      -     .
# 137616  chr21      havana    gene   9529928   9679906     .      +     .
#
#                                                 attribute  \
# 0       gene_id "DDX11L1"; transcript_id ""; db_xref "...
# 1       gene_id "WASH7P"; transcript_id ""; db_xref "G...
# 2       gene_id "MIR6859-1"; transcript_id ""; db_xref...
# 3       gene_id "MIR1302-2HG"; transcript_id ""; db_xr...
# 4       gene_id "MIR1302-2"; transcript_id ""; db_xref...
# ...                                                   ...
# 137612  gene_id "ENSG00000273104"; gene_version "1"; g...
# 137613  gene_id "ENSG00000243627"; gene_version "6"; g...
# 137614  gene_id "ENSG00000272958"; gene_version "1"; g...
# 137615  gene_id "ENSG00000280145"; gene_version "4"; g...
# 137616  gene_id "ENSG00000293062"; gene_version "2"; g...
#
#                                            attribute_dict        gene_name  \
# 0       {'gene_id': 'DDX11L1', 'transcript_id': '', 'd...          DDX11L1
# 1       {'gene_id': 'WASH7P', 'transcript_id': '', 'db...           WASH7P
# 2       {'gene_id': 'MIR6859-1', 'transcript_id': '', ...        MIR6859-1
# 3       {'gene_id': 'MIR1302-2HG', 'transcript_id': ''...      MIR1302-2HG
# 4       {'gene_id': 'MIR1302-2', 'transcript_id': '', ...        MIR1302-2
# ...                                                   ...              ...
# 137612  {'gene_id': 'ENSG00000273104', 'gene_version':...  ENSG00000273104
# 137613  {'gene_id': 'ENSG00000243627', 'gene_version':...           SMIM34
# 137614  {'gene_id': 'ENSG00000272958', 'gene_version':...  ENSG00000272958
# 137615  {'gene_id': 'ENSG00000280145', 'gene_version':...  ENSG00000280145
# 137616  {'gene_id': 'ENSG00000293062', 'gene_version':...  ENSG00000293062
#
#        transcript_id          gene_id  coding
# 0                             DDX11L1   False
# 1                              WASH7P   False
# 2                           MIR6859-1   False
# 3                         MIR1302-2HG   False
# 4                           MIR1302-2   False
# ...              ...              ...     ...
# 137612            NA  ENSG00000273104   False
# 137613            NA  ENSG00000243627    True
# 137614            NA  ENSG00000272958   False
# 137615            NA  ENSG00000280145   False
# 137616            NA  ENSG00000293062   False
#
# [137617 rows x 14 columns]

# %%
gene_gtf_df = gene_gtf_df.reset_index(drop=True)
assert(gene_gtf_df["gene_id"].nunique()==gene_gtf_df.shape[0])

# %%
merged_gtf["gene_id"] = merged_gtf["new_gene_id"]
merged_gtf = merged_gtf.drop(columns=["new_gene_id"])

# %%
def format_attribute(attribute_dict):
    attribute = ""
    for key, value in attribute_dict.items():
        attribute+=f'{key} "{value}"; '
    attribute = attribute[:-1]
    return attribute

# %%
merged_gtf["new_attribute"] = merged_gtf["attribute_dict"].apply(format_attribute)
print(merged_gtf)
# Out:
#            chr      source     feature      start        end score strand  \
# 0         chr1     ensembl  transcript  182944365  182944490     .      -
# 1         chr1     ensembl        exon  182944365  182944490     .      -
# 2        chr16     ensembl  transcript   47450347   47450461     .      -
# 3        chr16     ensembl        exon   47450347   47450461     .      -
# 4        chr17     ensembl  transcript   37940704   37940790     .      -
# ...        ...         ...         ...        ...        ...   ...    ...
# 7735344   chr1  BestRefSeq  transcript   26225320   26229840     .      +
# 7735345   chr1  BestRefSeq        exon   26225320   26225703     .      +
# 7735346   chr1  BestRefSeq        exon   26227404   26227555     .      +
# 7735347   chr1  BestRefSeq        exon   26227794   26227996     .      +
# 7735348   chr1  BestRefSeq        exon   26229502   26229840     .      +
#
#         frame                                          attribute  \
# 0           .  gene_id "ENSG00000285609"; gene_version "1"; t...
# 1           .  gene_id "ENSG00000285609"; gene_version "1"; t...
# 2           .  gene_id "ENSG00000288601"; gene_version "1"; t...
# 3           .  gene_id "ENSG00000288601"; gene_version "1"; t...
# 4           .  gene_id "ENSG00000277488"; gene_version "1"; t...
# ...       ...                                                ...
# 7735344     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735345     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735346     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735347     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735348     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
#
#                                             attribute_dict gene_name  \
# 0        {'gene_id': 'ENSG00000285609', 'gene_version':...   5S_rRNA
# 1        {'gene_id': 'ENSG00000285609', 'gene_version':...   5S_rRNA
# 2        {'gene_id': 'ENSG00000288601', 'gene_version':...   5S_rRNA
# 3        {'gene_id': 'ENSG00000288601', 'gene_version':...   5S_rRNA
# 4        {'gene_id': 'ENSG00000277488', 'gene_version':...   5S_rRNA
# ...                                                    ...       ...
# 7735344  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 7735345  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 7735346  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 7735347  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
# 7735348  {'gene_id': 'ZPLD2P', 'transcript_id': 'NR_110...    ZPLD2P
#
#            transcript_id          gene_id  coding  \
# 0        ENST00000648701  ENSG00000285609   False
# 1        ENST00000648701  ENSG00000285609   False
# 2        ENST00000674448  ENSG00000288601   False
# 3        ENST00000674448  ENSG00000288601   False
# 4        ENST00000618379  ENSG00000277488   False
# ...                  ...              ...     ...
# 7735344      NR_110698.1           ZPLD2P   False
# 7735345      NR_110698.1           ZPLD2P   False
# 7735346      NR_110698.1           ZPLD2P   False
# 7735347      NR_110698.1           ZPLD2P   False
# 7735348      NR_110698.1           ZPLD2P   False
#
#                                              new_attribute
# 0        gene_id "ENSG00000285609"; gene_version "1"; t...
# 1        gene_id "ENSG00000285609"; gene_version "1"; t...
# 2        gene_id "ENSG00000288601"; gene_version "1"; t...
# 3        gene_id "ENSG00000288601"; gene_version "1"; t...
# 4        gene_id "ENSG00000277488"; gene_version "1"; t...
# ...                                                    ...
# 7735344  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735345  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735346  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735347  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
# 7735348  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...
#
# [7735349 rows x 15 columns]

# %%
merged_gtf["attribute"] = merged_gtf["new_attribute"]
merged_gtf.drop(columns=["attribute_dict", "new_attribute"], inplace=True)
print(merged_gtf)
# Out:
#            chr      source     feature      start        end score strand  \
# 0         chr1     ensembl  transcript  182944365  182944490     .      -
# 1         chr1     ensembl        exon  182944365  182944490     .      -
# 2        chr16     ensembl  transcript   47450347   47450461     .      -
# 3        chr16     ensembl        exon   47450347   47450461     .      -
# 4        chr17     ensembl  transcript   37940704   37940790     .      -
# ...        ...         ...         ...        ...        ...   ...    ...
# 7735344   chr1  BestRefSeq  transcript   26225320   26229840     .      +
# 7735345   chr1  BestRefSeq        exon   26225320   26225703     .      +
# 7735346   chr1  BestRefSeq        exon   26227404   26227555     .      +
# 7735347   chr1  BestRefSeq        exon   26227794   26227996     .      +
# 7735348   chr1  BestRefSeq        exon   26229502   26229840     .      +
#
#         frame                                          attribute gene_name  \
# 0           .  gene_id "ENSG00000285609"; gene_version "1"; t...   5S_rRNA
# 1           .  gene_id "ENSG00000285609"; gene_version "1"; t...   5S_rRNA
# 2           .  gene_id "ENSG00000288601"; gene_version "1"; t...   5S_rRNA
# 3           .  gene_id "ENSG00000288601"; gene_version "1"; t...   5S_rRNA
# 4           .  gene_id "ENSG00000277488"; gene_version "1"; t...   5S_rRNA
# ...       ...                                                ...       ...
# 7735344     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...    ZPLD2P
# 7735345     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...    ZPLD2P
# 7735346     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...    ZPLD2P
# 7735347     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...    ZPLD2P
# 7735348     .  gene_id "ZPLD2P"; transcript_id "NR_110698.1";...    ZPLD2P
#
#            transcript_id          gene_id  coding
# 0        ENST00000648701  ENSG00000285609   False
# 1        ENST00000648701  ENSG00000285609   False
# 2        ENST00000674448  ENSG00000288601   False
# 3        ENST00000674448  ENSG00000288601   False
# 4        ENST00000618379  ENSG00000277488   False
# ...                  ...              ...     ...
# 7735344      NR_110698.1           ZPLD2P   False
# 7735345      NR_110698.1           ZPLD2P   False
# 7735346      NR_110698.1           ZPLD2P   False
# 7735347      NR_110698.1           ZPLD2P   False
# 7735348      NR_110698.1           ZPLD2P   False
#
# [7735349 rows x 13 columns]

# %%
gene_gtf_df.drop(columns=["attribute_dict"], inplace=True)
print(gene_gtf_df)
# Out:
#           chr      source feature     start       end score strand frame  \
# 0        chr1  BestRefSeq    gene     11874     14409     .      +     .
# 1        chr1  BestRefSeq    gene     14362     29370     .      -     .
# 2        chr1  BestRefSeq    gene     17369     17436     .      -     .
# 3        chr1      Gnomon    gene     29774     35418     .      +     .
# 4        chr1  BestRefSeq    gene     30366     30503     .      +     .
# ...       ...         ...     ...       ...       ...   ...    ...   ...
# 137612  chr21      havana    gene  34412200  34412587     .      +     .
# 137613  chr21      havana    gene  34414494  34423951     .      -     .
# 137614  chr21      havana    gene  34425508  34426017     .      +     .
# 137615  chr21      havana    gene   6630182   6670761     .      -     .
# 137616  chr21      havana    gene   9529928   9679906     .      +     .
#
#                                                 attribute        gene_name  \
# 0       gene_id "DDX11L1"; transcript_id ""; db_xref "...          DDX11L1
# 1       gene_id "WASH7P"; transcript_id ""; db_xref "G...           WASH7P
# 2       gene_id "MIR6859-1"; transcript_id ""; db_xref...        MIR6859-1
# 3       gene_id "MIR1302-2HG"; transcript_id ""; db_xr...      MIR1302-2HG
# 4       gene_id "MIR1302-2"; transcript_id ""; db_xref...        MIR1302-2
# ...                                                   ...              ...
# 137612  gene_id "ENSG00000273104"; gene_version "1"; g...  ENSG00000273104
# 137613  gene_id "ENSG00000243627"; gene_version "6"; g...           SMIM34
# 137614  gene_id "ENSG00000272958"; gene_version "1"; g...  ENSG00000272958
# 137615  gene_id "ENSG00000280145"; gene_version "4"; g...  ENSG00000280145
# 137616  gene_id "ENSG00000293062"; gene_version "2"; g...  ENSG00000293062
#
#        transcript_id          gene_id  coding
# 0                             DDX11L1   False
# 1                              WASH7P   False
# 2                           MIR6859-1   False
# 3                         MIR1302-2HG   False
# 4                           MIR1302-2   False
# ...              ...              ...     ...
# 137612            NA  ENSG00000273104   False
# 137613            NA  ENSG00000243627    True
# 137614            NA  ENSG00000272958   False
# 137615            NA  ENSG00000280145   False
# 137616            NA  ENSG00000293062   False
#
# [137617 rows x 13 columns]

# %%
merged_gtf =  merged_gtf.reset_index(drop=True)

# %%
merged_gtf_grouped = merged_gtf.groupby("gene_id")

# %%
chr_to_int_dict = {f"chr{x}": x for x in range(1,23)}
chr_to_int_dict["chrX"] = 23
chr_to_int_dict["chrY"] = 24

# %%
gtf_dict_for_sorting = {}

for gene_id, group in tqdm.tqdm(merged_gtf_grouped):
    gene_row = gene_gtf_df[gene_gtf_df["gene_id"]==gene_id].copy()
    if gene_row.shape[0]==0:
        continue
    start = group["start"].min()
    end = group["end"].max()
    gene_row["start"] = start
    gene_row["end"] = end
    chr = chr_to_int_dict[gene_row["chr"].values[0]]
    key = (chr, start, end, gene_id)
    group = group.groupby("transcript_id")
    sort_dict = {key: (value["start"].values[0], value["end"].values[0], value["transcript_id"].values[0]) for key, value in group}
    sorted_key = sorted(sort_dict.keys(), key=lambda x: sort_dict[x])
    gene_df = pd.concat([gene_row]+[group.get_group(key) for key in sorted_key], axis=0)
    gtf_dict_for_sorting[key] = gene_df

gtf_dict_for_sorting = [gtf_dict_for_sorting[key] for key in sorted(gtf_dict_for_sorting.keys())]
gtf_df = pd.concat(gtf_dict_for_sorting, axis=0)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 92816/92816 [41:31<00:00, 37.25it/s]

# %%
print(gtf_df)
# Out:
#            chr          source     feature    start      end score strand  \
# 88509     chr7  ensembl_havana        gene  5526409  5563902     .      -
# 52325     chr7          havana  transcript  5526409  5530601     .      -
# 52326     chr7          havana        exon  5530542  5530601     .      -
# 52327     chr7          havana        exon  5529535  5529684     .      -
# 52328     chr7          havana         CDS  5529535  5529657     .      -
# ...        ...             ...         ...      ...      ...   ...    ...
# 3642369  chr17          havana        exon  7675994  7676272     .      -
# 3642370  chr17          havana        exon  7675053  7675236     .      -
# 3642371  chr17          havana        exon  7674526  7674971     .      -
# 3642466  chr17          havana  transcript  7685249  7687523     .      -
# 3642467  chr17          havana        exon  7685249  7687523     .      -
#
#         frame                                          attribute  \
# 88509       .  gene_id "ENSG00000075624"; gene_version "17"; ...
# 52325       .  gene_id "ENSG00000075624"; gene_version "17"; ...
# 52326       .  gene_id "ENSG00000075624"; gene_version "17"; ...
# 52327       .  gene_id "ENSG00000075624"; gene_version "17"; ...
# 52328       0  gene_id "ENSG00000075624"; gene_version "17"; ...
# ...       ...                                                ...
# 3642369     .  gene_id "ENSG00000141510"; gene_version "19"; ...
# 3642370     .  gene_id "ENSG00000141510"; gene_version "19"; ...
# 3642371     .  gene_id "ENSG00000141510"; gene_version "19"; ...
# 3642466     .  gene_id "ENSG00000141510"; gene_version "19"; ...
# 3642467     .  gene_id "ENSG00000141510"; gene_version "19"; ...
#
#                                             attribute_dict gene_name  \
# 88509    {'gene_id': 'ENSG00000075624', 'gene_version':...      ACTB
# 52325    {'gene_id': 'ENSG00000075624', 'gene_version':...      ACTB
# 52326    {'gene_id': 'ENSG00000075624', 'gene_version':...      ACTB
# 52327    {'gene_id': 'ENSG00000075624', 'gene_version':...      ACTB
# 52328    {'gene_id': 'ENSG00000075624', 'gene_version':...      ACTB
# ...                                                    ...       ...
# 3642369  {'gene_id': 'ENSG00000141510', 'gene_version':...      TP53
# 3642370  {'gene_id': 'ENSG00000141510', 'gene_version':...      TP53
# 3642371  {'gene_id': 'ENSG00000141510', 'gene_version':...      TP53
# 3642466  {'gene_id': 'ENSG00000141510', 'gene_version':...      TP53
# 3642467  {'gene_id': 'ENSG00000141510', 'gene_version':...      TP53
#
#            transcript_id          gene_id  coding
# 88509                 NA  ENSG00000075624    True
# 52325    ENST00000674681  ENSG00000075624    True
# 52326    ENST00000674681  ENSG00000075624    True
# 52327    ENST00000674681  ENSG00000075624    True
# 52328    ENST00000674681  ENSG00000075624    True
# ...                  ...              ...     ...
# 3642369  ENST00000505014  ENSG00000141510    True
# 3642370  ENST00000505014  ENSG00000141510    True
# 3642371  ENST00000505014  ENSG00000141510    True
# 3642466  ENST00000571370  ENSG00000141510    True
# 3642467  ENST00000571370  ENSG00000141510    True
#
# [1443 rows x 14 columns]

# %%
gtf_df.to_pickle("/extdata4/baeklab/Hyeonseo/m6A/anno/merged_gtf.pkl")

# %%
columns = ["chr", "source", "feature", "start", "end", "score", "strand", "frame", "attribute"]
gtf_df_export = gtf_df[columns].copy()
gtf_df_export.to_csv("/extdata4/baeklab/Hyeonseo/m6A/anno/merged_gtf_manual.gtf", sep="\t", index=False, header=False, quoting=3)

# %%
agat_path = "/extdata4/baeklab/Hyeonseo/m6A/anno/agat_merged.gff"
columns = ["chr", "source", "feature", "start", "end", "score", "strand", "frame", "attribute"]
agat=pd.read_csv(agat_path, sep="\t", header=None, names=columns)
print(agat)
# Out:
#                      chr         source      feature       start         end  \
# 0        ##gff-version 3            NaN          NaN         NaN         NaN
# 1                   chrX         havana         gene    253743.0    255091.0
# 2                   chrX         havana   transcript    253743.0    255091.0
# 3                   chrX         havana         exon    253743.0    253846.0
# 4                   chrX         havana         exon    254937.0    255091.0
# ...                  ...            ...          ...         ...         ...
# 8201055            chr22         havana  start_codon  50782292.0  50782294.0
# 8201056            chr22  havana_tagene         gene  50797082.0  50798991.0
# 8201057            chr22  havana_tagene   transcript  50797082.0  50798991.0
# 8201058            chr22  havana_tagene         exon  50797082.0  50797504.0
# 8201059            chr22  havana_tagene         exon  50798788.0  50798991.0
#
#         score strand frame                                          attribute
# 0         NaN    NaN   NaN                                                NaN
# 1           .      +     .  ID=ENSG00000228572;gene_biotype=unprocessed_ps...
# 2           .      +     .  ID=ENST00000431238;Parent=ENSG00000228572;gene...
# 3           .      +     .  ID=ENSE00001702291;Parent=ENST00000431238;exon...
# 4           .      +     .  ID=ENSE00001655436;Parent=ENST00000431238;exon...
# ...       ...    ...   ...                                                ...
# 8201055     .      -     0  ID=merge_omniscients-start_codon-68919;Parent=...
# 8201056     .      -     .  ID=ENSG00000307555;gene_biotype=lncRNA;gene_id...
# 8201057     .      -     .  ID=ENST00000827060;Parent=ENSG00000307555;gene...
# 8201058     .      -     .  ID=ENSE00004238569;Parent=ENST00000827060;exon...
# 8201059     .      -     .  ID=ENSE00004238568;Parent=ENST00000827060;exon...
#
# [8201060 rows x 9 columns]

# %%
print(agat)
# Out:
#                      chr         source      feature       start         end  \
# 0        ##gff-version 3            NaN          NaN         NaN         NaN
# 1                   chrX         havana         gene    253743.0    255091.0
# 2                   chrX         havana   transcript    253743.0    255091.0
# 3                   chrX         havana         exon    253743.0    253846.0
# 4                   chrX         havana         exon    254937.0    255091.0
# ...                  ...            ...          ...         ...         ...
# 8201055            chr22         havana  start_codon  50782292.0  50782294.0
# 8201056            chr22  havana_tagene         gene  50797082.0  50798991.0
# 8201057            chr22  havana_tagene   transcript  50797082.0  50798991.0
# 8201058            chr22  havana_tagene         exon  50797082.0  50797504.0
# 8201059            chr22  havana_tagene         exon  50798788.0  50798991.0
#
#         score strand frame                                          attribute
# 0         NaN    NaN   NaN                                                NaN
# 1           .      +     .  ID=ENSG00000228572;gene_biotype=unprocessed_ps...
# 2           .      +     .  ID=ENST00000431238;Parent=ENSG00000228572;gene...
# 3           .      +     .  ID=ENSE00001702291;Parent=ENST00000431238;exon...
# 4           .      +     .  ID=ENSE00001655436;Parent=ENST00000431238;exon...
# ...       ...    ...   ...                                                ...
# 8201055     .      -     0  ID=merge_omniscients-start_codon-68919;Parent=...
# 8201056     .      -     .  ID=ENSG00000307555;gene_biotype=lncRNA;gene_id...
# 8201057     .      -     .  ID=ENST00000827060;Parent=ENSG00000307555;gene...
# 8201058     .      -     .  ID=ENSE00004238569;Parent=ENST00000827060;exon...
# 8201059     .      -     .  ID=ENSE00004238568;Parent=ENST00000827060;exon...
#
# [8201060 rows x 9 columns]

# %%
agat = agat.iloc[1:].copy()

# %%
def gff_attribute_to_dict(attribute):
    attribute = attribute
    attribute_dict = {}
    for attr in attribute.split(';'):
        try:
            key, value = attr.split('=')
        except:
            print(attribute)
            print(attr)
            raise ValueError
        key = key.strip()
        attribute_dict[key] = value
    return attribute_dict

# %%
agat[["start", "end"]] = agat[["start", "end"]].astype(int)
agat["attribute_dict"] = agat["attribute"].apply(gff_attribute_to_dict)
print(agat)
# Out:
#            chr         source      feature     start       end score strand  \
# 1         chrX         havana         gene    253743    255091     .      +
# 2         chrX         havana   transcript    253743    255091     .      +
# 3         chrX         havana         exon    253743    253846     .      +
# 4         chrX         havana         exon    254937    255091     .      +
# 5         chrX  havana_tagene         gene    267677    276210     .      -
# ...        ...            ...          ...       ...       ...   ...    ...
# 8201055  chr22         havana  start_codon  50782292  50782294     .      -
# 8201056  chr22  havana_tagene         gene  50797082  50798991     .      -
# 8201057  chr22  havana_tagene   transcript  50797082  50798991     .      -
# 8201058  chr22  havana_tagene         exon  50797082  50797504     .      -
# 8201059  chr22  havana_tagene         exon  50798788  50798991     .      -
#
#         frame                                          attribute  \
# 1           .  ID=ENSG00000228572;gene_biotype=unprocessed_ps...
# 2           .  ID=ENST00000431238;Parent=ENSG00000228572;gene...
# 3           .  ID=ENSE00001702291;Parent=ENST00000431238;exon...
# 4           .  ID=ENSE00001655436;Parent=ENST00000431238;exon...
# 5           .  ID=ENSG00000303837;gene_biotype=lncRNA;gene_id...
# ...       ...                                                ...
# 8201055     0  ID=merge_omniscients-start_codon-68919;Parent=...
# 8201056     .  ID=ENSG00000307555;gene_biotype=lncRNA;gene_id...
# 8201057     .  ID=ENST00000827060;Parent=ENSG00000307555;gene...
# 8201058     .  ID=ENSE00004238569;Parent=ENST00000827060;exon...
# 8201059     .  ID=ENSE00004238568;Parent=ENST00000827060;exon...
#
#                                             attribute_dict
# 1        {'ID': 'ENSG00000228572', 'gene_biotype': 'unp...
# 2        {'ID': 'ENST00000431238', 'Parent': 'ENSG00000...
# 3        {'ID': 'ENSE00001702291', 'Parent': 'ENST00000...
# 4        {'ID': 'ENSE00001655436', 'Parent': 'ENST00000...
# 5        {'ID': 'ENSG00000303837', 'gene_biotype': 'lnc...
# ...                                                    ...
# 8201055  {'ID': 'merge_omniscients-start_codon-68919', ...
# 8201056  {'ID': 'ENSG00000307555', 'gene_biotype': 'lnc...
# 8201057  {'ID': 'ENST00000827060', 'Parent': 'ENSG00000...
# 8201058  {'ID': 'ENSE00004238569', 'Parent': 'ENST00000...
# 8201059  {'ID': 'ENSE00004238568', 'Parent': 'ENST00000...
#
# [8201059 rows x 10 columns]

# %%
print(agat["feature"].value_counts())
agat["transcript_id"] = agat["attribute_dict"].apply(lambda x: x.get("transcript_id", "NA"))
print(agat["transcript_id"].nunique())
# Out:
# feature
# exon               4034985
# CDS                2379896
# transcript          542608
# five_prime_UTR      251894
# start_codon         210417
# three_prime_utr     204960
# stop_codon          204215
# five_prime_utr      165446
# three_prime_UTR     127541
# gene                 78969
# Selenocysteine         128
# Name: count, dtype: int64
# 542610

# %%
## Find duplicates in agat["transcript_id"]
a = agat[agat["feature"]=="transcript"]["transcript_id"].unique()
b = agat["transcript_id"].unique()
diff = set(b).difference(set(a))
print(diff)
# Out:
# {'NA', '""'}

# %%
print(agat)
# Out:
#            chr         source      feature     start       end score strand  \
# 1         chrX         havana         gene    253743    255091     .      +
# 2         chrX         havana   transcript    253743    255091     .      +
# 3         chrX         havana         exon    253743    253846     .      +
# 4         chrX         havana         exon    254937    255091     .      +
# 5         chrX  havana_tagene         gene    267677    276210     .      -
# ...        ...            ...          ...       ...       ...   ...    ...
# 8201055  chr22         havana  start_codon  50782292  50782294     .      -
# 8201056  chr22  havana_tagene         gene  50797082  50798991     .      -
# 8201057  chr22  havana_tagene   transcript  50797082  50798991     .      -
# 8201058  chr22  havana_tagene         exon  50797082  50797504     .      -
# 8201059  chr22  havana_tagene         exon  50798788  50798991     .      -
#
#         frame                                          attribute  \
# 1           .  ID=ENSG00000228572;gene_biotype=unprocessed_ps...
# 2           .  ID=ENST00000431238;Parent=ENSG00000228572;gene...
# 3           .  ID=ENSE00001702291;Parent=ENST00000431238;exon...
# 4           .  ID=ENSE00001655436;Parent=ENST00000431238;exon...
# 5           .  ID=ENSG00000303837;gene_biotype=lncRNA;gene_id...
# ...       ...                                                ...
# 8201055     0  ID=merge_omniscients-start_codon-68919;Parent=...
# 8201056     .  ID=ENSG00000307555;gene_biotype=lncRNA;gene_id...
# 8201057     .  ID=ENST00000827060;Parent=ENSG00000307555;gene...
# 8201058     .  ID=ENSE00004238569;Parent=ENST00000827060;exon...
# 8201059     .  ID=ENSE00004238568;Parent=ENST00000827060;exon...
#
#                                             attribute_dict    transcript_id
# 1        {'ID': 'ENSG00000228572', 'gene_biotype': 'unp...               NA
# 2        {'ID': 'ENST00000431238', 'Parent': 'ENSG00000...  ENST00000431238
# 3        {'ID': 'ENSE00001702291', 'Parent': 'ENST00000...  ENST00000431238
# 4        {'ID': 'ENSE00001655436', 'Parent': 'ENST00000...  ENST00000431238
# 5        {'ID': 'ENSG00000303837', 'gene_biotype': 'lnc...               NA
# ...                                                    ...              ...
# 8201055  {'ID': 'merge_omniscients-start_codon-68919', ...  ENST00000413505
# 8201056  {'ID': 'ENSG00000307555', 'gene_biotype': 'lnc...               NA
# 8201057  {'ID': 'ENST00000827060', 'Parent': 'ENSG00000...  ENST00000827060
# 8201058  {'ID': 'ENSE00004238569', 'Parent': 'ENST00000...  ENST00000827060
# 8201059  {'ID': 'ENSE00004238568', 'Parent': 'ENST00000...  ENST00000827060
#
# [8201059 rows x 11 columns]

# %%
agat["Parent"] = agat["attribute_dict"].apply(lambda x: x.get("Parent", None))
print(agat)
# Out:
#            chr         source      feature     start       end score strand  \
# 1         chrX         havana         gene    253743    255091     .      +
# 2         chrX         havana   transcript    253743    255091     .      +
# 3         chrX         havana         exon    253743    253846     .      +
# 4         chrX         havana         exon    254937    255091     .      +
# 5         chrX  havana_tagene         gene    267677    276210     .      -
# ...        ...            ...          ...       ...       ...   ...    ...
# 8201055  chr22         havana  start_codon  50782292  50782294     .      -
# 8201056  chr22  havana_tagene         gene  50797082  50798991     .      -
# 8201057  chr22  havana_tagene   transcript  50797082  50798991     .      -
# 8201058  chr22  havana_tagene         exon  50797082  50797504     .      -
# 8201059  chr22  havana_tagene         exon  50798788  50798991     .      -
#
#         frame                                          attribute  \
# 1           .  ID=ENSG00000228572;gene_biotype=unprocessed_ps...
# 2           .  ID=ENST00000431238;Parent=ENSG00000228572;gene...
# 3           .  ID=ENSE00001702291;Parent=ENST00000431238;exon...
# 4           .  ID=ENSE00001655436;Parent=ENST00000431238;exon...
# 5           .  ID=ENSG00000303837;gene_biotype=lncRNA;gene_id...
# ...       ...                                                ...
# 8201055     0  ID=merge_omniscients-start_codon-68919;Parent=...
# 8201056     .  ID=ENSG00000307555;gene_biotype=lncRNA;gene_id...
# 8201057     .  ID=ENST00000827060;Parent=ENSG00000307555;gene...
# 8201058     .  ID=ENSE00004238569;Parent=ENST00000827060;exon...
# 8201059     .  ID=ENSE00004238568;Parent=ENST00000827060;exon...
#
#                                             attribute_dict    transcript_id  \
# 1        {'ID': 'ENSG00000228572', 'gene_biotype': 'unp...               NA
# 2        {'ID': 'ENST00000431238', 'Parent': 'ENSG00000...  ENST00000431238
# 3        {'ID': 'ENSE00001702291', 'Parent': 'ENST00000...  ENST00000431238
# 4        {'ID': 'ENSE00001655436', 'Parent': 'ENST00000...  ENST00000431238
# 5        {'ID': 'ENSG00000303837', 'gene_biotype': 'lnc...               NA
# ...                                                    ...              ...
# 8201055  {'ID': 'merge_omniscients-start_codon-68919', ...  ENST00000413505
# 8201056  {'ID': 'ENSG00000307555', 'gene_biotype': 'lnc...               NA
# 8201057  {'ID': 'ENST00000827060', 'Parent': 'ENSG00000...  ENST00000827060
# 8201058  {'ID': 'ENSE00004238569', 'Parent': 'ENST00000...  ENST00000827060
# 8201059  {'ID': 'ENSE00004238568', 'Parent': 'ENST00000...  ENST00000827060
#
#                  gene_id gene_name  coding           Parent
# 1        ENSG00000228572      None   False             None
# 2        ENSG00000228572      None   False  ENSG00000228572
# 3        ENSG00000228572      None   False  ENST00000431238
# 4        ENSG00000228572      None   False  ENST00000431238
# 5        ENSG00000303837      None   False             None
# ...                  ...       ...     ...              ...
# 8201055  ENSG00000079974    RABL2B    True  ENST00000413505
# 8201056  ENSG00000307555      None   False             None
# 8201057  ENSG00000307555      None   False  ENSG00000307555
# 8201058  ENSG00000307555      None   False  ENST00000827060
# 8201059  ENSG00000307555      None   False  ENST00000827060
#
# [8201059 rows x 15 columns]

# %%
agat_transcript = agat[agat["feature"]=="transcript"].copy()
print(agat_transcript)
# Out:
#            chr         source     feature     start       end score strand  \
# 2         chrX         havana  transcript    253743    255091     .      +
# 6         chrX  havana_tagene  transcript    267677    276210     .      -
# 11        chrX         havana  transcript    276322    303353     .      +
# 32        chrX         havana  transcript    276324    291537     .      +
# 38        chrX         havana  transcript    276353    291629     .      +
# ...        ...            ...         ...       ...       ...   ...    ...
# 8201011  chr22         havana  transcript  50771210  50783630     .      -
# 8201028  chr22         havana  transcript  50775771  50783600     .      -
# 8201045  chr22         havana  transcript  50777660  50783630     .      -
# 8201049  chr22         havana  transcript  50782234  50783045     .      -
# 8201057  chr22  havana_tagene  transcript  50797082  50798991     .      -
#
#         frame                                          attribute  \
# 2           .  ID=ENST00000431238;Parent=ENSG00000228572;gene...
# 6           .  ID=ENST00000797435;Parent=ENSG00000303837;gene...
# 11          .  ID=ENST00000399012;Parent=ENSG00000182378;ccds...
# 32          .  ID=ENST00000484611;Parent=ENSG00000182378;gene...
# 38          .  ID=ENST00000430923;Parent=ENSG00000182378;gene...
# ...       ...                                                ...
# 8201011     .  ID=ENST00000395590;Parent=ENSG00000079974;gene...
# 8201028     .  ID=ENST00000468451;Parent=ENSG00000079974;gene...
# 8201045     .  ID=ENST00000464740;Parent=ENSG00000079974;gene...
# 8201049     .  ID=ENST00000413505;Parent=ENSG00000079974;gene...
# 8201057     .  ID=ENST00000827060;Parent=ENSG00000307555;gene...
#
#                                             attribute_dict    transcript_id  \
# 2        {'ID': 'ENST00000431238', 'Parent': 'ENSG00000...  ENST00000431238
# 6        {'ID': 'ENST00000797435', 'Parent': 'ENSG00000...  ENST00000797435
# 11       {'ID': 'ENST00000399012', 'Parent': 'ENSG00000...  ENST00000399012
# 32       {'ID': 'ENST00000484611', 'Parent': 'ENSG00000...  ENST00000484611
# 38       {'ID': 'ENST00000430923', 'Parent': 'ENSG00000...  ENST00000430923
# ...                                                    ...              ...
# 8201011  {'ID': 'ENST00000395590', 'Parent': 'ENSG00000...  ENST00000395590
# 8201028  {'ID': 'ENST00000468451', 'Parent': 'ENSG00000...  ENST00000468451
# 8201045  {'ID': 'ENST00000464740', 'Parent': 'ENSG00000...  ENST00000464740
# 8201049  {'ID': 'ENST00000413505', 'Parent': 'ENSG00000...  ENST00000413505
# 8201057  {'ID': 'ENST00000827060', 'Parent': 'ENSG00000...  ENST00000827060
#
#                  gene_id gene_name  coding           Parent
# 2        ENSG00000228572      None   False  ENSG00000228572
# 6        ENSG00000303837      None   False  ENSG00000303837
# 11       ENSG00000182378    PLCXD1    True  ENSG00000182378
# 32       ENSG00000182378    PLCXD1   False  ENSG00000182378
# 38       ENSG00000182378    PLCXD1    True  ENSG00000182378
# ...                  ...       ...     ...              ...
# 8201011  ENSG00000079974    RABL2B    True  ENSG00000079974
# 8201028  ENSG00000079974    RABL2B   False  ENSG00000079974
# 8201045  ENSG00000079974    RABL2B   False  ENSG00000079974
# 8201049  ENSG00000079974    RABL2B    True  ENSG00000079974
# 8201057  ENSG00000307555      None   False  ENSG00000307555
#
# [542608 rows x 15 columns]

# %%
agat_gene = agat[agat["feature"]=="gene"].copy()
print(agat_gene[agat_gene["gene_name"].isna()])
# Out:
#            chr         source feature     start       end score strand frame  \
# 1         chrX         havana    gene    253743    255091     .      +     .
# 5         chrX  havana_tagene    gene    267677    276210     .      -     .
# 294       chrX  havana_tagene    gene    278946    281825     .      -     .
# 779       chrX         havana    gene    386962    511616     .      +     .
# 851       chrX  havana_tagene    gene    600187    600999     .      +     .
# ...        ...            ...     ...       ...       ...   ...    ...   ...
# 8198701  chr22  havana_tagene    gene  50664426  50674856     .      -     .
# 8198712  chr22         havana    gene  50672714  50674336     .      +     .
# 8199007  chr22         havana    gene  50735813  50738173     .      -     .
# 8199061  chr22         havana    gene  50740593  50743520     .      -     .
# 8201056  chr22  havana_tagene    gene  50797082  50798991     .      -     .
#
#                                                  attribute  \
# 1        ID=ENSG00000228572;gene_biotype=unprocessed_ps...
# 5        ID=ENSG00000303837;gene_biotype=lncRNA;gene_id...
# 294      ID=ENSG00000303863;gene_biotype=lncRNA;gene_id...
# 779      ID=ENSG00000281849;db_xref=GeneID:102724521;de...
# 851      ID=ENSG00000296130;gene_biotype=lncRNA;gene_id...
# ...                                                    ...
# 8198701  ID=ENSG00000301328;gene_biotype=lncRNA;gene_id...
# 8198712  ID=ENSG00000286508;gene_biotype=lncRNA;gene_id...
# 8199007  ID=ENSG00000225929;db_xref=GeneID:105373100;de...
# 8199061  ID=ENSG00000254499;gene_biotype=lncRNA;gene_id...
# 8201056  ID=ENSG00000307555;gene_biotype=lncRNA;gene_id...
#
#                                             attribute_dict transcript_id  \
# 1        {'ID': 'ENSG00000228572', 'gene_biotype': 'unp...            NA
# 5        {'ID': 'ENSG00000303837', 'gene_biotype': 'lnc...            NA
# 294      {'ID': 'ENSG00000303863', 'gene_biotype': 'lnc...            NA
# 779      {'ID': 'ENSG00000281849', 'db_xref': 'GeneID:1...            ""
# 851      {'ID': 'ENSG00000296130', 'gene_biotype': 'lnc...            NA
# ...                                                    ...           ...
# 8198701  {'ID': 'ENSG00000301328', 'gene_biotype': 'lnc...            NA
# 8198712  {'ID': 'ENSG00000286508', 'gene_biotype': 'lnc...            NA
# 8199007  {'ID': 'ENSG00000225929', 'db_xref': 'GeneID:1...            ""
# 8199061  {'ID': 'ENSG00000254499', 'gene_biotype': 'lnc...            NA
# 8201056  {'ID': 'ENSG00000307555', 'gene_biotype': 'lnc...            NA
#
#                  gene_id gene_name  coding
# 1        ENSG00000228572      None   False
# 5        ENSG00000303837      None   False
# 294      ENSG00000303863      None   False
# 779      ENSG00000281849      None   False
# 851      ENSG00000296130      None   False
# ...                  ...       ...     ...
# 8198701  ENSG00000301328      None   False
# 8198712  ENSG00000286508      None   False
# 8199007  ENSG00000225929      None   False
# 8199061  ENSG00000254499      None   False
# 8201056  ENSG00000307555      None   False
#
# [38019 rows x 14 columns]

# %%
## IF gene_name is NA, use gene of attribute_dict
agat_gene["gene_name"] = agat_gene.apply(lambda x: x["attribute_dict"].get("gene",None) if x["gene_name"] is None else x["gene_name"], axis=1)
print(agat_gene[agat_gene["gene_name"].isna()])
# Out:
#            chr         source feature     start       end score strand frame  \
# 1         chrX         havana    gene    253743    255091     .      +     .
# 5         chrX  havana_tagene    gene    267677    276210     .      -     .
# 294       chrX  havana_tagene    gene    278946    281825     .      -     .
# 851       chrX  havana_tagene    gene    600187    600999     .      +     .
# 926       chrX  havana_tagene    gene    964424    965367     .      -     .
# ...        ...            ...     ...       ...       ...   ...    ...   ...
# 8198696  chr22  havana_tagene    gene  50641978  50653123     .      +     .
# 8198701  chr22  havana_tagene    gene  50664426  50674856     .      -     .
# 8198712  chr22         havana    gene  50672714  50674336     .      +     .
# 8199061  chr22         havana    gene  50740593  50743520     .      -     .
# 8201056  chr22  havana_tagene    gene  50797082  50798991     .      -     .
#
#                                                  attribute  \
# 1        ID=ENSG00000228572;gene_biotype=unprocessed_ps...
# 5        ID=ENSG00000303837;gene_biotype=lncRNA;gene_id...
# 294      ID=ENSG00000303863;gene_biotype=lncRNA;gene_id...
# 851      ID=ENSG00000296130;gene_biotype=lncRNA;gene_id...
# 926      ID=ENSG00000293700;gene_biotype=lncRNA;gene_id...
# ...                                                    ...
# 8198696  ID=ENSG00000308444;gene_biotype=lncRNA;gene_id...
# 8198701  ID=ENSG00000301328;gene_biotype=lncRNA;gene_id...
# 8198712  ID=ENSG00000286508;gene_biotype=lncRNA;gene_id...
# 8199061  ID=ENSG00000254499;gene_biotype=lncRNA;gene_id...
# 8201056  ID=ENSG00000307555;gene_biotype=lncRNA;gene_id...
#
#                                             attribute_dict transcript_id  \
# 1        {'ID': 'ENSG00000228572', 'gene_biotype': 'unp...            NA
# 5        {'ID': 'ENSG00000303837', 'gene_biotype': 'lnc...            NA
# 294      {'ID': 'ENSG00000303863', 'gene_biotype': 'lnc...            NA
# 851      {'ID': 'ENSG00000296130', 'gene_biotype': 'lnc...            NA
# 926      {'ID': 'ENSG00000293700', 'gene_biotype': 'lnc...            NA
# ...                                                    ...           ...
# 8198696  {'ID': 'ENSG00000308444', 'gene_biotype': 'lnc...            NA
# 8198701  {'ID': 'ENSG00000301328', 'gene_biotype': 'lnc...            NA
# 8198712  {'ID': 'ENSG00000286508', 'gene_biotype': 'lnc...            NA
# 8199061  {'ID': 'ENSG00000254499', 'gene_biotype': 'lnc...            NA
# 8201056  {'ID': 'ENSG00000307555', 'gene_biotype': 'lnc...            NA
#
#                  gene_id gene_name  coding
# 1        ENSG00000228572      None   False
# 5        ENSG00000303837      None   False
# 294      ENSG00000303863      None   False
# 851      ENSG00000296130      None   False
# 926      ENSG00000293700      None   False
# ...                  ...       ...     ...
# 8198696  ENSG00000308444      None   False
# 8198701  ENSG00000301328      None   False
# 8198712  ENSG00000286508      None   False
# 8199061  ENSG00000254499      None   False
# 8201056  ENSG00000307555      None   False
#
# [24775 rows x 14 columns]

# %%
## IF gene_name is NA, use gene of attribute_dict
agat_gene["gene_name"] = agat_gene.apply(lambda x: x["gene_id"] if x["gene_name"] is None else x["gene_name"], axis=1)
print(agat_gene[agat_gene["gene_name"].isna()])
# Out:
# Empty DataFrame
# Columns: [chr, source, feature, start, end, score, strand, frame, attribute, attribute_dict, transcript_id, gene_id, gene_name, coding]
# Index: []

# %%
print(agat_gene["gene_id"].nunique())
# Out:
# 78969

# %%
def get_id(attribute_dict):
    id_main = attribute_dict["gene_id"]
    id_merged = attribute_dict.get("merged_gene_id", None)
    id_all = [id_main]
    if id_merged is not None:
        id_merged = id_merged.split(",")
        id_all+=id_merged
    id_ensembl = [x for x in id_all if x.startswith("ENSG")]
    id_refseq = [x for x in id_all if not x.startswith("ENSG")]
    if len(id_ensembl)==0:
        id_ensembl = None
    else:
        id_ensembl = id_ensembl[0]
    if len(id_refseq)==0:
        id_refseq = None
    else:
        id_refseq = id_refseq[0]
    return id_ensembl, id_refseq

# %%
agat_gene[['ensembl_id', 'refseq_id']] = agat_gene["attribute_dict"].apply(lambda x: pd.Series(get_id(x)))
print(agat_gene)
# Out:
#            chr               source feature      start        end score  \
# 7211895  chr17       ensembl_havana    gene   81833492   81835050     .
# 7451099  chr19       ensembl_havana    gene    7534004    7561767     .
# 2684636   chr5        havana_tagene    gene   36343672   36347157     .
# 782838    chr1              mirbase    gene  154104521  154104592     .
# 5934063  chr14  BestRefSeq%2CGnomon    gene   31100117   31207804     .
# ...        ...                  ...     ...        ...        ...   ...
# 2906704   chr5               Gnomon    gene  142154411  142193061     .
# 3787887   chr7        havana_tagene    gene  158433349  158439624     .
# 7913086  chr20        havana_tagene    gene   53863569   53866418     .
# 7204562  chr17               Gnomon    gene   81146930   81150292     .
# 7051014  chr17        havana_tagene    gene   47982494   48012258     .
#
#         strand frame                                          attribute  \
# 7211895      -     .  ID=ENSG00000182676;db_xref=GeneID:116729,HGNC:...
# 7451099      +     .  ID=ENSG00000032444;db_xref=GeneID:10908,HGNC:H...
# 2684636      -     .  ID=ENSG00000287634;gene_biotype=lncRNA;gene_id...
# 782838       -     .  ID=ENSG00000263987;db_xref=GeneID:100847024,HG...
# 5934063      -     .  ID=HECTD1;db_xref=GeneID:25831,HGNC:HGNC:20157...
# ...        ...   ...                                                ...
# 2906704      -     .  ID=LOC107986455;db_xref=GeneID:107986455;descr...
# 3787887      +     .  ID=ENSG00000289418;gene_biotype=lncRNA;gene_id...
# 7913086      -     .  ID=ENSG00000304955;db_xref=GeneID:124904935;de...
# 7204562      +     .  ID=LOC124904080;db_xref=GeneID:124904080;descr...
# 7051014      +     .  ID=ENSG00000289599;db_xref=GeneID:124904017;de...
#
#                                             attribute_dict transcript_id  \
# 7211895  {'ID': 'ENSG00000182676', 'db_xref': 'GeneID:1...            ""
# 7451099  {'ID': 'ENSG00000032444', 'db_xref': 'GeneID:1...            ""
# 2684636  {'ID': 'ENSG00000287634', 'gene_biotype': 'lnc...            NA
# 782838   {'ID': 'ENSG00000263987', 'db_xref': 'GeneID:1...            ""
# 5934063  {'ID': 'HECTD1', 'db_xref': 'GeneID:25831,HGNC...            ""
# ...                                                    ...           ...
# 2906704  {'ID': 'LOC107986455', 'db_xref': 'GeneID:1079...            ""
# 3787887  {'ID': 'ENSG00000289418', 'gene_biotype': 'lnc...            NA
# 7913086  {'ID': 'ENSG00000304955', 'db_xref': 'GeneID:1...            ""
# 7204562  {'ID': 'LOC124904080', 'db_xref': 'GeneID:1249...            ""
# 7051014  {'ID': 'ENSG00000289599', 'db_xref': 'GeneID:1...            ""
#
#                  gene_id        gene_name  coding       ensembl_id  \
# 7211895  ENSG00000182676          PPP1R27   False  ENSG00000182676
# 7451099  ENSG00000032444           PNPLA6   False  ENSG00000032444
# 2684636  ENSG00000287634  ENSG00000287634   False  ENSG00000287634
# 782838   ENSG00000263987          MIR5698   False  ENSG00000263987
# 5934063           HECTD1           HECTD1   False  ENSG00000092148
# ...                  ...              ...     ...              ...
# 2906704     LOC107986455     LOC107986455   False  ENSG00000300546
# 3787887  ENSG00000289418  ENSG00000289418   False  ENSG00000289418
# 7913086  ENSG00000304955     LOC124904935   False  ENSG00000304955
# 7204562     LOC124904080     LOC124904080   False             None
# 7051014  ENSG00000289599     LOC124904017   False  ENSG00000289599
#
#             refseq_id
# 7211895       PPP1R27
# 7451099        PNPLA6
# 2684636          None
# 782838        MIR5698
# 5934063        HECTD1
# ...               ...
# 2906704  LOC107986455
# 3787887          None
# 7913086  LOC124904935
# 7204562  LOC124904080
# 7051014  LOC124904017
#
# [1000 rows x 16 columns]

# %%
print(agat_gene[agat_gene["gene_id"].str.startswith("ENSG")]["attribute_dict"].values[2])
# Out:
# {'ID': 'ENSG00000182378', 'db_xref': 'GeneID:55344,HGNC:HGNC:23148,MIM:300974', 'description': 'phosphatidylinositol specific phospholipase C X domain containing 1', 'gbkey': 'Gene', 'gene': 'PLCXD1', 'gene_biotype': 'protein_coding', 'gene_id': 'ENSG00000182378', 'gene_name': 'PLCXD1', 'gene_source': 'ensembl_havana', 'gene_synonym': 'LL0XNC01-136G2.1', 'gene_version': '15', 'merged_ID': 'PLCXD1', 'merged_gene_id': 'PLCXD1', 'transcript_id': '""'}

# %%
gene_id_to_name_dict = dict(zip(agat_gene["gene_id"], agat_gene["gene_name"]))

# %%
def determine_coding(attribute_dict):
    transcript_id = attribute_dict.get("transcript_id", "XXXX")
    if transcript_id.startswith("NM") or transcript_id.startswith("XM"):
        return True
    else:
        transcript_biotype = attribute_dict.get("transcript_biotype", "XXXX")
        return transcript_biotype=="protein_coding"

# %%
agat["coding"] = agat["attribute_dict"].apply(determine_coding)

# %%
def make_refflat(df):
    refflat_dict = {"transcript_id":[], "gene_id":[], "gene_name":[], "chr":[], "strand":[], "txStart":[], "txEnd":[], "cdsStart":[], "cdsEnd":[], "exonCount":[], "exonStarts":[], "exonEnds":[], "coding": []}
    for transcript_id, group in tqdm.tqdm(df, total=df.ngroups):
        refflat_dict["transcript_id"].append(transcript_id) 
        gene_id = group[group["feature"]=="transcript"]["Parent"].dropna().unique()
        try: 
            assert len(gene_id)==1
        except:
            print(group)
            raise ValueError
        gene_id = gene_id[0]
        gene_name = gene_id_to_name_dict[gene_id]
        refflat_dict["gene_id"].append(gene_name)
        refflat_dict["gene_name"].append(gene_id)
        refflat_dict["chr"].append(group["chr"].values[0])
        refflat_dict["strand"].append(group["strand"].values[0])
        start = group["start"].min()
        end = group["end"].max()
        refflat_dict["txStart"].append(start)
        refflat_dict["txEnd"].append(end)
        if group[group["feature"]=="CDS"].shape[0]==0:
            refflat_dict["cdsStart"].append(start)
            refflat_dict["cdsEnd"].append(end)
            refflat_dict["coding"].append(group["coding"].any())
        else:
            refflat_dict["cdsStart"].append(group[group["feature"]=="CDS"]["start"].min())
            refflat_dict["cdsEnd"].append(group[group["feature"]=="CDS"]["end"].max())
            refflat_dict["coding"].append(True)
        refflat_dict["exonCount"].append(group[group["feature"]=="exon"].shape[0])
        refflat_dict["exonStarts"].append(",".join(group[group["feature"]=="exon"]["start"].sort_values().astype(str).values))
        refflat_dict["exonEnds"].append(",".join(group[group["feature"]=="exon"]["end"].sort_values().astype(str).values))
    refflat = pd.DataFrame(refflat_dict)
    return refflat

# %%
agat_exoncds = agat[agat["feature"].isin(["transcript","exon", "CDS"])]
agat_exoncds = agat_exoncds.groupby("transcript_id")

# %%
agat_refflat = make_refflat(agat_exoncds)
# Out:
#  31%|██████████████████████████████████████████████▉                                                                                                       | 169754/542608 [08:27<18:34, 334.63it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[288], line 1
# ----> 1 agat_refflat = make_refflat(agat_exoncds)
#
# Cell In[283], line 31, in make_refflat(df)
#      29     refflat_dict["exonCount"].append(group[group["feature"]=="exon"].shape[0])
#      30     refflat_dict["exonStarts"].append(",".join(group[group["feature"]=="exon"]["start"].sort_values().astype(str).values))
# ---> 31     refflat_dict["exonEnds"].append(",".join(group[group["feature"]=="exon"]["end"].sort_values().astype(str).values))
#      32 refflat = pd.DataFrame(refflat_dict)
#      33 return refflat
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/frame.py:3884, in DataFrame.__getitem__(self, key)
#    3882 # Do we have a (boolean) 1d indexer?
#    3883 if com.is_bool_indexer(key):
# -> 3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#    3888 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/frame.py:3946, in DataFrame._getitem_bool_array(self, key)
#    3943     return self.copy(deep=None)
#    3945 indexer = key.nonzero()[0]
# -> 3946 return self._take_with_is_copy(indexer, axis=0)
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/generic.py:4088, in NDFrame._take_with_is_copy(self, indices, axis)
#    4077 @final
#    4078 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4079     """
#    4080     Internal version of the `take` method that sets the `_is_copy`
#    4081     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4086     See the docstring of `take` for full explanation of the parameters.
#    4087     """
# -> 4088     result = self.take(indices=indices, axis=axis)
#    4089     # Maybe set copy if we didn't actually change the index.
#    4090     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/internals/managers.py:877, in BaseBlockManager.take(self, indexer, axis, verify)
#     874 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     876 new_labels = self.axes[axis].take(indexer)
# --> 877 return self.reindex_indexer(
#     878     new_axis=new_labels,
#     879     indexer=indexer,
#     880     axis=axis,
#     881     allow_dups=True,
#     882     copy=None,
#     883 )
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/internals/managers.py:670, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     663     new_blocks = self._slice_take_blocks_ax0(
#     664         indexer,
#     665         fill_value=fill_value,
#     666         only_slice=only_slice,
#     667         use_na_proxy=use_na_proxy,
#     668     )
#     669 else:
# --> 670     new_blocks = [
#     671         blk.take_nd(
#     672             indexer,
#     673             axis=1,
#     674             fill_value=(
#     675                 fill_value if fill_value is not None else blk.fill_value
#     676             ),
#     677         )
#     678         for blk in self.blocks
#     679     ]
#     681 new_axes = list(self.axes)
#     682 new_axes[axis] = new_axis
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/internals/managers.py:671, in <listcomp>(.0)
#     663     new_blocks = self._slice_take_blocks_ax0(
#     664         indexer,
#     665         fill_value=fill_value,
#     666         only_slice=only_slice,
#     667         use_na_proxy=use_na_proxy,
#     668     )
#     669 else:
#     670     new_blocks = [
# --> 671         blk.take_nd(
#     672             indexer,
#     673             axis=1,
#     674             fill_value=(
#     675                 fill_value if fill_value is not None else blk.fill_value
#     676             ),
#     677         )
#     678         for blk in self.blocks
#     679     ]
#     681 new_axes = list(self.axes)
#     682 new_axes[axis] = new_axis
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/internals/blocks.py:1079, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1077     return self.make_block(new_values, new_mgr_locs)
#    1078 else:
# -> 1079     return self.make_block_same_class(new_values, new_mgr_locs)
#
# File ~/baeklab/Junhak/anaconda3/envs/Hyeonseo_torch/lib/python3.9/site-packages/pandas/core/internals/blocks.py:279, in Block.make_block_same_class(self, values, placement, refs)
#     276     placement = self._mgr_locs
#     278 # We assume maybe_coerce_values has already been called
# --> 279 return type(self)(values, placement=placement, ndim=self.ndim, refs=refs)
#
# KeyboardInterrupt:

# %%
print(agat[agat["transcript_id"]=="ENST00000000233"])
# Out:
#           chr          source          feature      start        end score  \
# 3709542  chr7  ensembl_havana       transcript  127588411  127591700     .
# 3709543  chr7  ensembl_havana             exon  127588411  127588565     .
# 3709544  chr7  ensembl_havana             exon  127589083  127589163     .
# 3709545  chr7  ensembl_havana             exon  127589485  127589594     .
# 3709546  chr7  ensembl_havana             exon  127590066  127590137     .
# 3709547  chr7  ensembl_havana             exon  127590963  127591088     .
# 3709548  chr7  ensembl_havana             exon  127591213  127591700     .
# 3709549  chr7  ensembl_havana              CDS  127588499  127588565     .
# 3709550  chr7  ensembl_havana              CDS  127589083  127589163     .
# 3709551  chr7  ensembl_havana              CDS  127589485  127589594     .
# 3709552  chr7  ensembl_havana              CDS  127590066  127590137     .
# 3709553  chr7  ensembl_havana              CDS  127590963  127591088     .
# 3709554  chr7  ensembl_havana              CDS  127591213  127591299     .
# 3709555  chr7  ensembl_havana   five_prime_utr  127588411  127588498     .
# 3709556  chr7  ensembl_havana      start_codon  127588499  127588501     .
# 3709557  chr7  ensembl_havana       stop_codon  127591297  127591299     .
# 3709558  chr7  ensembl_havana  three_prime_utr  127591300  127591700     .
#
#         strand frame                                          attribute  \
# 3709542      +     .  ID=ENST00000000233;Parent=ENSG00000004059;ccds...
# 3709543      +     .  ID=ENSE00001872691;Parent=ENST00000000233;ccds...
# 3709544      +     .  ID=merge_omniscients-exon-583290;Parent=ENST00...
# 3709545      +     .  ID=merge_omniscients-exon-583291;Parent=ENST00...
# 3709546      +     .  ID=merge_omniscients-exon-583292;Parent=ENST00...
# 3709547      +     .  ID=ENSE00003676786;Parent=ENST00000000233;ccds...
# 3709548      +     .  ID=ENSE00000882271;Parent=ENST00000000233;ccds...
# 3709549      +     0  ID=merge_omniscients-cds-469722;Parent=ENST000...
# 3709550      +     2  ID=merge_omniscients-cds-469723;Parent=ENST000...
# 3709551      +     2  ID=merge_omniscients-cds-469724;Parent=ENST000...
# 3709552      +     0  ID=merge_omniscients-cds-469725;Parent=ENST000...
# 3709553      +     0  ID=merge_omniscients-cds-469726;Parent=ENST000...
# 3709554      +     0  ID=merge_omniscients-cds-469727;Parent=ENST000...
# 3709555      +     .  ID=merge_omniscients-five_prime_utr-91122;Pare...
# 3709556      +     0  ID=merge_omniscients-start_codon-51371;Parent=...
# 3709557      +     0  ID=merge_omniscients-stop_codon-48281;Parent=E...
# 3709558      +     .  ID=merge_omniscients-three_prime_utr-73000;Par...
#
#                                             attribute_dict    transcript_id  \
# 3709542  {'ID': 'ENST00000000233', 'Parent': 'ENSG00000...  ENST00000000233
# 3709543  {'ID': 'ENSE00001872691', 'Parent': 'ENST00000...  ENST00000000233
# 3709544  {'ID': 'merge_omniscients-exon-583290', 'Paren...  ENST00000000233
# 3709545  {'ID': 'merge_omniscients-exon-583291', 'Paren...  ENST00000000233
# 3709546  {'ID': 'merge_omniscients-exon-583292', 'Paren...  ENST00000000233
# 3709547  {'ID': 'ENSE00003676786', 'Parent': 'ENST00000...  ENST00000000233
# 3709548  {'ID': 'ENSE00000882271', 'Parent': 'ENST00000...  ENST00000000233
# 3709549  {'ID': 'merge_omniscients-cds-469722', 'Parent...  ENST00000000233
# 3709550  {'ID': 'merge_omniscients-cds-469723', 'Parent...  ENST00000000233
# 3709551  {'ID': 'merge_omniscients-cds-469724', 'Parent...  ENST00000000233
# 3709552  {'ID': 'merge_omniscients-cds-469725', 'Parent...  ENST00000000233
# 3709553  {'ID': 'merge_omniscients-cds-469726', 'Parent...  ENST00000000233
# 3709554  {'ID': 'merge_omniscients-cds-469727', 'Parent...  ENST00000000233
# 3709555  {'ID': 'merge_omniscients-five_prime_utr-91122...  ENST00000000233
# 3709556  {'ID': 'merge_omniscients-start_codon-51371', ...  ENST00000000233
# 3709557  {'ID': 'merge_omniscients-stop_codon-48281', '...  ENST00000000233
# 3709558  {'ID': 'merge_omniscients-three_prime_utr-7300...  ENST00000000233
#
#                  gene_id gene_name  coding           Parent
# 3709542  ENSG00000004059      ARF5    True  ENSG00000004059
# 3709543  ENSG00000004059      ARF5    True  ENST00000000233
# 3709544  ENSG00000004059      ARF5    True  ENST00000000233
# 3709545  ENSG00000004059      ARF5    True  ENST00000000233
# 3709546  ENSG00000004059      ARF5    True  ENST00000000233
# 3709547  ENSG00000004059      ARF5    True  ENST00000000233
# 3709548  ENSG00000004059      ARF5    True  ENST00000000233
# 3709549  ENSG00000004059      ARF5    True  ENST00000000233
# 3709550  ENSG00000004059      ARF5    True  ENST00000000233
# 3709551  ENSG00000004059      ARF5    True  ENST00000000233
# 3709552  ENSG00000004059      ARF5    True  ENST00000000233
# 3709553  ENSG00000004059      ARF5    True  ENST00000000233
# 3709554  ENSG00000004059      ARF5    True  ENST00000000233
# 3709555  ENSG00000004059      ARF5    True  ENST00000000233
# 3709556  ENSG00000004059      ARF5    True  ENST00000000233
# 3709557  ENSG00000004059      ARF5    True  ENST00000000233
# 3709558  ENSG00000004059      ARF5    True  ENST00000000233

# %%
print(agat[agat["gene_name"]=="STPG1"])
# Out:
#          chr               source     feature     start       end score  \
# 424571  chr1  BestRefSeq%2CGnomon        gene  24356999  24416934     .
# 424708  chr1       ensembl_havana  transcript  24356999  24415097     .
# 424709  chr1       ensembl_havana        exon  24356999  24358619     .
# 424710  chr1       ensembl_havana        exon  24360851  24361041     .
# 424711  chr1       ensembl_havana        exon  24369674  24369839     .
# ...      ...                  ...         ...       ...       ...   ...
# 424803  chr1               havana        exon  24401079  24401456     .
# 424804  chr1               havana        exon  24410703  24410779     .
# 424805  chr1               havana  transcript  24414911  24416595     .
# 424806  chr1               havana        exon  24414911  24415098     .
# 424807  chr1               havana        exon  24416477  24416595     .
#
#        strand frame                                          attribute  \
# 424571      -     .  ID=STPG1;db_xref=GeneID:90529,HGNC:HGNC:28070,...
# 424708      -     .  ID=ENST00000374409;Parent=STPG1;ccds_id=CCDS55...
# 424709      -     .  ID=merge_omniscients-exon-475552;Parent=ENST00...
# 424710      -     .  ID=merge_omniscients-exon-475551;Parent=ENST00...
# 424711      -     .  ID=merge_omniscients-exon-475550;Parent=ENST00...
# ...       ...   ...                                                ...
# 424803      -     .  ID=ENSE00001863843;Parent=ENST00000475760;exon...
# 424804      -     .  ID=ENSE00001843748;Parent=ENST00000475760;exon...
# 424805      -     .  ID=ENST00000492753;Parent=STPG1;gene_biotype=p...
# 424806      -     .  ID=ENSE00001923991;Parent=ENST00000492753;exon...
# 424807      -     .  ID=ENSE00001936284;Parent=ENST00000492753;exon...
#
#                                            attribute_dict    transcript_id  \
# 424571  {'ID': 'STPG1', 'db_xref': 'GeneID:90529,HGNC:...               ""
# 424708  {'ID': 'ENST00000374409', 'Parent': 'STPG1', '...  ENST00000374409
# 424709  {'ID': 'merge_omniscients-exon-475552', 'Paren...  ENST00000374409
# 424710  {'ID': 'merge_omniscients-exon-475551', 'Paren...  ENST00000374409
# 424711  {'ID': 'merge_omniscients-exon-475550', 'Paren...  ENST00000374409
# ...                                                   ...              ...
# 424803  {'ID': 'ENSE00001863843', 'Parent': 'ENST00000...  ENST00000475760
# 424804  {'ID': 'ENSE00001843748', 'Parent': 'ENST00000...  ENST00000475760
# 424805  {'ID': 'ENST00000492753', 'Parent': 'STPG1', '...  ENST00000492753
# 424806  {'ID': 'ENSE00001923991', 'Parent': 'ENST00000...  ENST00000492753
# 424807  {'ID': 'ENSE00001936284', 'Parent': 'ENST00000...  ENST00000492753
#
#                 gene_id gene_name  coding           Parent
# 424571            STPG1     STPG1   False             None
# 424708  ENSG00000001460     STPG1    True            STPG1
# 424709  ENSG00000001460     STPG1    True  ENST00000374409
# 424710  ENSG00000001460     STPG1    True  ENST00000374409
# 424711  ENSG00000001460     STPG1    True  ENST00000374409
# ...                 ...       ...     ...              ...
# 424803  ENSG00000001460     STPG1   False  ENST00000475760
# 424804  ENSG00000001460     STPG1   False  ENST00000475760
# 424805  ENSG00000001460     STPG1   False            STPG1
# 424806  ENSG00000001460     STPG1   False  ENST00000492753
# 424807  ENSG00000001460     STPG1   False  ENST00000492753
#
# [101 rows x 15 columns]

# %%
print(agat[agat["gene_name"]=="STPG1"]["attribute_dict"].values[0])
# Out:
# {'ID': 'STPG1', 'db_xref': 'GeneID:90529,HGNC:HGNC:28070,MIM:615826', 'description': 'sperm tail PG-rich repeat containing 1', 'gbkey': 'Gene', 'gene': 'STPG1', 'gene_biotype': 'protein_coding', 'gene_id': 'STPG1', 'gene_name': 'STPG1', 'gene_source': 'ensembl_havana', 'gene_synonym': 'C1orf201,MAPO2', 'gene_version': '18', 'merged_ID': 'ENSG00000001460', 'merged_gene_id': 'ENSG00000001460', 'transcript_id': '""'}
