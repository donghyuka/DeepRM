# %%
import os, sys, time
import itertools
import re
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def site_8m(mirseq_comrev):
    return site_7m8(mirseq_comrev) + "A"


def site_7m8(mirseq_comrev):
    return mirseq_comrev[-8:][:-1]


def site_7A1(mirseq_comrev):
    return site_6m(mirseq_comrev) + "A"


def site_6m(mirseq_comrev):
    return mirseq_comrev[-7:][:-1]


def complementaryReverse(sSeq):  # Make complementary 5'-3' sequence
    sTempSeq = sSeq[::-1]
    retSeq = ''
    for base in sTempSeq:
        retSeq = retSeq + complement(base)
    return retSeq


def complement(base):
    complbase = ''
    if base == 'A':
        complbase = 'T'
    elif base == 'T':
        complbase = 'A'
    elif base == 'G':
        complbase = 'C'
    elif base == 'C':
        complbase = 'G'
    return complbase

# %%
mirna = "UACACACACAUGUAAACCAUU"

# %%
utr_seq = "..."

# %%
a = re.finditer("TGTGTGTA", utr_seq)

# %%
for i in a:
    print(i)
# Out:
# <re.Match object; span=(616, 624), match='TGTGTGTA'>
